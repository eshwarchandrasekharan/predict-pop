# %%
video_search_URL = 'https://api.buzzfeed.com/omnisearch/search/videos'

params = {'q': 'video name', sort = platform_objects.published_at:asc}

results = requests.get(video_search_URL, headers=headers, params = params).json().get('results',[])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-041402479b72> in <module>()
#       1 video_search_URL = 'https://api.buzzfeed.com/omnisearch/search/videos'
#       2
# ----> 3 params = {'q': 'video name', sort == platform_objects.published_at:asc}
#       4
#       5 results = requests.get(video_search_URL, headers=headers, params = params).json().get('results',[])
#
# NameError: name 'sort' is not defined

# %%
import requests
headers = { 'X-Auth-Token': '1f7dbd91-c9f4-4b3d-a82a-356127b685f2'
           }
r = requests.get("https://api-public.buzzfeed.com/flexpro/v1/experiments?content_ids=buzz:4507076", headers=headers).json()
r
# Out:
# {'next': None,
#  'previous': None,
#  'results': [{'authors': [{'email': 'leticia.miranda@buzzfeed.com'},
#     {'email': 'venessa.wong@buzzfeed.com'}],
#    'auto_resolved': False,
#    'content_id': 'buzz:4507076',
#    'created_at': '2017-04-10T20:44:57.248323',
#    'created_at_ts': 1491857097.248323,
#    'ended_at': '2017-04-10T20:45:11.112263',
#    'ended_at_ts': 1491857111.112263,
#    'id': 9795,
#    'status': 'ended',
#    'variations': [{'clicks': 0,
#      'id': 49935,
#      'impressions': 0,
#      'thumbnail': {'image': '/static/2017-04/10/16/campaign_images/buzzfeed-prod-fastlane-03/you-likely-wont-be-able-to-talk-on-the-phone-in-a-2-14858-1491855274-0.jpg',
#       'original_image': '/static/2017-04/10/15/enhanced/buzzfeed-prod-fastlane-02/original-9753-1491851071-10.jpg',
# ...

# %%
import requests
# url = 'https://api-public-stage.buzzfeed.com/omnisearch/search/videos/'
params = {'post_id': 4508834}
url = 'https://api-public-stage.buzzfeed.com/comment_corpus/search/'
# url = 'https://api.buzzfeed.com/omnisearch/search/videos/'
headers = { 'X-Auth-Token': 'de7b2670-72b9-420c-9215-5a57c03f27a5'}
# resp = requests.get(url, params = params, headers = headers)
resp = requests.get(url, headers = headers, params = params).json()#.get('results',[])
resp
# Out:
# {'message': 'UNKNOWN_UPSTREAM', 'status': 'error'}

# %%
import requests
headers = { 'X-Auth-Token': 'de7b2670-72b9-420c-9215-5a57c03f27a5'
           }

requests.get("https://api-public-stage.buzzfeed.com/comment_corpus/comment?post_id=4507076", headers=headers).json()
# Out:
# {'message': 'UNKNOWN_UPSTREAM', 'status': 'error'}

# %%
import requests
# url = 'https://api-public-stage.buzzfeed.com/omnisearch/search/videos/'
params = {'q': 'I Vote Because', 'page_size': 2}
url = 'https://api-public.buzzfeed.com/omnisearch/search'
# url = 'https://api.buzzfeed.com/omnisearch/search/videos/'
headers = { 'X-Auth-Token': 'ef2a7012-835f-4b5a-b527-22be59815e10'}
# resp = requests.get(url, params = params, headers = headers)
resp = requests.get(url, headers = headers, params = params).json().get('results',[])
resp
# Out:
# [{'_content_id': 8527,
#   '_content_source': 'video',
#   'aspect_ratio': '1:1',
#   'created_at': 1478568138,
#   'created_by_id': 1285,
#   'credits': [{'_document_source': 'video',
#     '_document_source_id': 11157,
#     'email': 'kuwilileni.hauwanga@buzzfeed.com',
#     'name': 'Kuwilileni Hauwanga',
#     'source': 'BuzzFeed',
#     'type': 'Lead Producer',
#     'user_id': 1285},
#    {'_document_source': 'video',
#     '_document_source_id': 11158,
#     'email': '',
#     'name': '',
#     'source': 'Audio Network',
#     'type': 'Audio',
#     'user_id': None}],
#   'description': 'Why Do You Vote? ',
#   'doc_type': 'video',
#   'duration': 79,
#   'is_branded': False,
#   'is_variant': False,
#   'keywords': 'voting, elections, women, men, hope, change, different, equality, people, united states, america, life, liberty, pursuit',
#   'language': 'eng',
#   'live_at': 1478640638,
#   'platform_ids': ['video__8527', 'facebook__989695217841559'],
# ...

# %%
import requests
# url = 'https://api-public-stage.buzzfeed.com/omnisearch/search/videos/'
# external_id = "1412984988933193_2020812238150462"
external_id  = '571035253040893_989695217841559'
query = 'facebook__' + external_id.split('_')[1]
# query ='facebook__989695217841559'
params = {'platform_ids': query, 'page_size': 2}

url = 'https://api-public.buzzfeed.com/omnisearch/search/videos'
# url = 'https://api.buzzfeed.com/omnisearch/search/videos/'
headers = { 'X-Auth-Token': 'ef2a7012-835f-4b5a-b527-22be59815e10'}
# resp = requests.get(url, params = params, headers = headers).json()
resp = requests.get(url, headers = headers, params = params).json().get('results',[])
df = pd.DataFrame(resp)
print('Content ID for external ID ', external_id , ' is : ', df['_content_id'].values[0])
resp
# Out:
# Content ID for external ID  571035253040893_989695217841559  is :  8527
# [{'_content_id': 8527,
#   '_content_source': 'video',
#   'aspect_ratio': '1:1',
#   'created_at': 1478568138,
#   'created_by_id': 1285,
#   'credits': [{'_document_source': 'video',
#     '_document_source_id': 11157,
#     'email': 'kuwilileni.hauwanga@buzzfeed.com',
#     'name': 'Kuwilileni Hauwanga',
#     'source': 'BuzzFeed',
#     'type': 'Lead Producer',
#     'user_id': 1285},
#    {'_document_source': 'video',
#     '_document_source_id': 11158,
#     'email': '',
#     'name': '',
#     'source': 'Audio Network',
#     'type': 'Audio',
#     'user_id': None}],
#   'description': 'Why Do You Vote? ',
#   'doc_type': 'video',
#   'duration': 79,
#   'is_branded': False,
#   'is_variant': False,
#   'keywords': 'voting, elections, women, men, hope, change, different, equality, people, united states, america, life, liberty, pursuit',
#   'language': 'eng',
#   'live_at': 1478640638,
# ...

# %%
import pandas as pd
df = pd.DataFrame(resp)
df['_content_id'].values[0]
# Out:
# 8527

# %%
query
# Out:
# 'facebook__146334719907'

# %%
external_id = "1412984988933193_2020812238150462"
external_id.split('_')[1]
# Out:
# '2020812238150462'

# %%
query
# Out:
# 'facebook__146334719907'

# %%
q1 = "facebook__989695217841559"
query ='facebook__989695217841559'
if q1 == query:
    print("same")
else:
    print("BLAH")
# Out:
# same

# %%
####
external_ids = [
#                 '1318800798260799_1506437046163839', 
#                 '1318800798260799_1550446255096251',
#                 '1318800798260799_2162798873860983',
#                 '1412406255640941_1909518732596355',
#     '1412406255640941_1909532342594994',
#                 '571035253040893_989695217841559',
#     '1433294486996353_1744002335925565',
#     '1433294486996353_1690417457950720',
#     '210885442609900_390321311332978',
    '21898300328_10154547495895329',
    '1412984988933193_2020296224868730',
]

test_df = pd.DataFrame()
test_df['external_id'] = external_ids

def get_content_id(X):
    url = 'https://api-public.buzzfeed.com/omnisearch/search/videos'
    headers = { 'X-Auth-Token': 'ef2a7012-835f-4b5a-b527-22be59815e10'}
    query = 'facebook__' + X.split('_')[1]
    params = {'platform_ids': query, 'page_size': 2}
    try:
        resp = requests.get(url, headers = headers, params = params).json().get('results',[])
        df = pd.DataFrame(resp)
        return df['_content_id'].values[0]
    except:
        return -1
test_df['content_id'] = test_df['external_id'].apply(get_content_id)

# %%
test_df
# Out:
#                          external_id  content_id
# 0      21898300328_10154547495895329          -1
# 1  1412984988933193_2020296224868730          -1

# %%
df[['created_at', 'title']]
# Out:
#    created_at             title
# 0  1478568138  I Vote Because..

# %%
for item in pd.DataFrame(resp['platform_object']):
    print(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-3a2c2d0707d7> in <module>()
# ----> 1 for item in pd.DataFrame(resp['platform_object']):
#       2     print(item)
#
# TypeError: list indices must be integers or slices, not str

# %%
resp
# Out:
# [{'_content_id': 8527,
#   '_content_source': 'video',
#   'aspect_ratio': '1:1',
#   'created_at': 1478568138,
#   'created_by_id': 1285,
#   'credits': [{'_document_source': 'video',
#     '_document_source_id': 11157,
#     'email': 'kuwilileni.hauwanga@buzzfeed.com',
#     'name': 'Kuwilileni Hauwanga',
#     'source': 'BuzzFeed',
#     'type': 'Lead Producer',
#     'user_id': 1285},
#    {'_document_source': 'video',
#     '_document_source_id': 11158,
#     'email': '',
#     'name': '',
#     'source': 'Audio Network',
#     'type': 'Audio',
#     'user_id': None}],
#   'description': 'Why Do You Vote? ',
#   'doc_type': 'video',
#   'duration': 79,
#   'is_branded': False,
#   'is_variant': False,
#   'keywords': 'voting, elections, women, men, hope, change, different, equality, people, united states, america, life, liberty, pursuit',
#   'language': 'eng',
#   'live_at': 1478640638,
#   'platform_ids': ['video__8527', 'facebook__989695217841559'],
# ...

# %%
'21898300328_10154547495895329'
# Out:
# '21898300328_10154547495895329'

# %%
video_df = pd.read_csv('jan_may_2017_video_stats.csv')
video_df = video_df.fillna(0)

# video_df.shape, video_df['external_id'].unique().shape
train = video_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')

# %%
###FORECASTING - TASK 0 (Given performance of a video on a FB page within 1st hour, predict its performance in 2 days!)
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
features = ['firsthour_' + var for var in features]

# for feat in features:
#     train[feat] = np.log(train[feat] + 1)

####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

print("twodays_video_views_10s_organic!")
# res = ols(y = np.log(train['twodays_video_views_10s_organic']+1), x = train[features])
res = ols(y = train['twodays_video_views_10s_organic'], x = train[features])
print(res)

print("twodays_video_complete_views_30s_organic!")
# res = ols(y = np.log(train['twodays_video_complete_views_30s_organic']+1), x = train[features])
res = ols(y = train['twodays_video_complete_views_30s_organic'], x = train[features])
print(res)


print("twodays_video_complete_views_organic!")
res = ols(y = train['twodays_video_complete_views_organic'], x = train[features])
# res = ols(y = np.log(train['twodays_video_complete_views_organic']+1), x = train[features])
print(res)
# Out:
# twodays_video_views_10s_organic!
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <firsthour_consumptions_by_type__link_clicks>
#              + <firsthour_stories_by_action_type__share> + <firsthour_video_views_10s_organic>
#              + <firsthour_video_complete_views_30s_organic>
#              + <firsthour_video_complete_views_organic> + <intercept>
#
# Number of Observations:         7163
# Number of Degrees of Freedom:   6
#
# R-squared:         0.2107
# Adj R-squared:     0.2101
#
# Rmse:          1876040.1551
#
# F-stat (5, 7157):   382.0058, p-value:     0.0000
#
# Degrees of Freedom: model 5, resid 7157
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ...

# %%
###FORECASTING - TASK 0 (Given performance of a video on a FB page within 1st hour, predict its performance in 2 days!)
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
features = ['firsthour_' + var for var in features]

for feat in features:
    train[feat] = np.log(train[feat] + 1)

####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

print("twodays_video_views_10s_organic!")
res = ols(y = np.log(train['twodays_video_views_10s_organic']+1), x = train[features])
# res = ols(y = train['twodays_video_views_10s_organic'], x = train[features])
print(res)

print("twodays_video_complete_views_30s_organic!")
res = ols(y = np.log(train['twodays_video_complete_views_30s_organic']+1), x = train[features])
# res = ols(y = train['twodays_video_complete_views_30s_organic'], x = train[features])
print(res)


print("twodays_video_complete_views_organic!")
# res = ols(y = train['twodays_video_complete_views_organic'], x = train[features])
res = ols(y = np.log(train['twodays_video_complete_views_organic']+1), x = train[features])
print(res)
# Out:
# twodays_video_views_10s_organic!
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <firsthour_consumptions_by_type__link_clicks>
#              + <firsthour_stories_by_action_type__share> + <firsthour_video_views_10s_organic>
#              + <firsthour_video_complete_views_30s_organic>
#              + <firsthour_video_complete_views_organic> + <intercept>
#
# Number of Observations:         7163
# Number of Degrees of Freedom:   6
#
# R-squared:         0.8352
# Adj R-squared:     0.8351
#
# Rmse:              1.2398
#
# F-stat (5, 7157):  7254.3620, p-value:     0.0000
#
# Degrees of Freedom: model 5, resid 7157
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ...

# %%
##given performance in the previous page, where should I post next?
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.cross_validation import train_test_split
import math

from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# from sklearn import linear_model
# clf = linear_model.LinearRegression()
# print("LINEAR REGRESSION!")

from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth=10)
print("TREE REGRESSION!")


train_df = pd.read_csv('jan_may_2017_video_stats.csv')
train_df = train_df.fillna(0)

# video_df.shape, video_df['external_id'].unique().shape
train_df = train_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')

one_hour_features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
one_hour_features = ['firsthour_' + var for var in one_hour_features]

train_features = one_hour_features

# for feats in (one_hour_features):
#     train_df[feats] = np.log(train_df[feats] + 1)

# lm = linear_model.LinearRegression(fit_intercept=True, normalize=True)
cv = 10

# train_df['10s_bucket'] = np.log(train_df['twodays_video_views_10s_organic'] + 1).astype(int)
# train_df['30s_bucket'] = np.log(train_df['twodays_video_complete_views_30s_organic'] + 1).astype(int)
# train_df['complete_views_bucket'] = np.log(train_df['twodays_video_complete_views_organic'] + 1).astype(int)

print("No. of data-points = ", len(train_df))

y_10s = train_df['twodays_video_views_10s_organic']
y_30s = train_df['twodays_video_complete_views_30s_organic']
y_complete = train_df['twodays_video_complete_views_organic']
# y_10s = train_df['10s_bucket']
# y_30s = train_df['30s_bucket']
# y_complete = train_df['complete_views_bucket']

###generate DFs for analysis - X and Y
X = train_df[train_features]

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

accuracy_10s = []
error_10s = []
accuracy_30s = []
error_30s = []
accuracy_complete = []
error_complete = []

for train_index, test_index in kf.split(X):
    print("Fold = ", fold)
#     print("Shares: Fold = ", fold)
    y = y_10s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_10s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_10s.append(error_percent)
    
#     print("Clicks: Fold = ", fold)
    y = y_30s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_30s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_30s.append(error_percent)
    
    #     print("Clicks: Fold = ", fold)
    y = y_complete
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_complete.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_complete.append(error_percent)
    
    fold += 1
    
print("10s organic views performance: Accuracy = ", np.mean(accuracy_10s), " ; Error (/100) = ", np.mean(error_10s))
print("30s organic views performance: Accuracy = ", np.mean(accuracy_30s), " ; Error (/100) = ", np.mean(error_30s))
print("Complete organic views performance: Accuracy = ", np.mean(accuracy_complete), " ; Error (/100) = ", np.mean(error_complete))
# Out:
# TREE REGRESSION!
# No. of data-points =  7163
# Fold =  0
# Fold =  1
# Fold =  2
# Fold =  3
# Fold =  4
# Fold =  5
# Fold =  6
# Fold =  7
# Fold =  8
# Fold =  9
# 10s organic views performance: Accuracy =  0.868263716813  ; Error (/100) =  0.377652363522
# 30s organic views performance: Accuracy =  0.901188312116  ; Error (/100) =  0.323083030607
# Complete organic views performance: Accuracy =  0.879131806909  ; Error (/100) =  0.332275517433

# %%
##given performance in the previous page, where should I post next?
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.cross_validation import train_test_split
import math

from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# from sklearn import linear_model
# clf = linear_model.LinearRegression()
# print("LINEAR REGRESSION!")

from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth=10)
print("TREE REGRESSION!")


train_df = pd.read_csv('jan_may_2017_video_stats.csv')
train_df = train_df.fillna(0)

# video_df.shape, video_df['external_id'].unique().shape
train_df = train_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')

one_hour_features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
one_hour_features = ['firsthour_' + var for var in one_hour_features]

train_features = one_hour_features

for feats in (one_hour_features):
    train_df[feats] = np.log(train_df[feats] + 1)

# lm = linear_model.LinearRegression(fit_intercept=True, normalize=True)
cv = 10

train_df['10s_bucket'] = np.log(train_df['twodays_video_views_10s_organic'] + 1).astype(int)
train_df['30s_bucket'] = np.log(train_df['twodays_video_complete_views_30s_organic'] + 1).astype(int)
train_df['complete_views_bucket'] = np.log(train_df['twodays_video_complete_views_organic'] + 1).astype(int)

print("No. of data-points = ", len(train_df))

# y_10s = train_df['twodays_video_views_10s_organic']
# y_30s = train_df['twodays_video_complete_views_30s_organic']
# y_complete = train_df['twodays_video_complete_views_organic']
y_10s = train_df['10s_bucket']
y_30s = train_df['30s_bucket']
y_complete = train_df['complete_views_bucket']

###generate DFs for analysis - X and Y
X = train_df[train_features]

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

accuracy_10s = []
error_10s = []
accuracy_30s = []
error_30s = []
accuracy_complete = []
error_complete = []

###focus on the well-populated or represented areas in the distribution of performance metrics
# train_df = train_df[(train_df['10s_bucket'] >= 7.5) & (train_df['10s_bucket'] <= 15)]

for train_index, test_index in kf.split(X):
    print("Fold = ", fold)
#     print("Shares: Fold = ", fold)
    y = y_10s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_10s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_10s.append(error_percent)
    
#     print("Clicks: Fold = ", fold)
    y = y_30s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_30s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_30s.append(error_percent)
    
    #     print("Clicks: Fold = ", fold)
    y = y_complete
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_complete.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_complete.append(error_percent)
    
    fold += 1
    
print("10s organic views performance: Accuracy = ", np.mean(accuracy_10s), " ; Error (/100) = ", np.mean(error_10s))
print("30s organic views performance: Accuracy = ", np.mean(accuracy_30s), " ; Error (/100) = ", np.mean(error_30s))
print("Complete organic views performance: Accuracy = ", np.mean(accuracy_complete), " ; Error (/100) = ", np.mean(error_complete))
# Out:
# TREE REGRESSION!
# No. of data-points =  7163
# Fold =  0
# Fold =  1
# Fold =  2
# Fold =  3
# Fold =  4
# Fold =  5
# Fold =  6
# Fold =  7
# Fold =  8
# Fold =  9
# 10s organic views performance: Accuracy =  0.874467621527  ; Error (/100) =  0.0596638080047
# 30s organic views performance: Accuracy =  0.882961369171  ; Error (/100) =  0.0623025324422
# Complete organic views performance: Accuracy =  0.878067719979  ; Error (/100) =  0.0663437864738

# %%
##given performance in the previous page, where should I post next?
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.cross_validation import train_test_split
import math

from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# from sklearn import linear_model
# clf = linear_model.LinearRegression()
# print("LINEAR REGRESSION!")

from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth=10)
print("TREE REGRESSION!")

train_df = pd.read_csv('jan_may_2017_video_stats.csv')
train_df = train_df.fillna(0)

# video_df.shape, video_df['external_id'].unique().shape
train_df = train_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')

one_hour_features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
one_hour_features = ['firsthour_' + var for var in one_hour_features]

train_features = one_hour_features

for feats in (one_hour_features):
    train_df[feats] = np.log(train_df[feats] + 1)

# lm = linear_model.LinearRegression(fit_intercept=True, normalize=True)
cv = 10

train_df['10s_bucket'] = np.log(train_df['twodays_video_views_10s_organic'] + 1).astype(int)
train_df['30s_bucket'] = np.log(train_df['twodays_video_complete_views_30s_organic'] + 1).astype(int)
train_df['complete_views_bucket'] = np.log(train_df['twodays_video_complete_views_organic'] + 1).astype(int)


###focus on the well-populated or represented areas in the distribution of performance metrics
train_df = train_df[(train_df['10s_bucket'] >= 8) & (train_df['10s_bucket'] <= 14)]
train_df = train_df[(train_df['30s_bucket'] >= 8) & (train_df['30s_bucket'] <= 14)]
train_df = train_df[(train_df['complete_views_bucket'] >= 8) & (train_df['complete_views_bucket'] <= 14)]
# train_df = train_df[(train_df['10s_bucket'] > 14)]
# train_df = train_df[(train_df['30s_bucket'] > 14)]
# train_df = train_df[(train_df['complete_views_bucket'] > 14)]
# train_df = train_df[(train_df['10s_bucket'] <= 14)]
# train_df = train_df[(train_df['30s_bucket'] <= 14)]
# train_df = train_df[(train_df['complete_views_bucket'] <= 14)]

print("No. of data-points = ", len(train_df))

# y_10s = train_df['twodays_video_views_10s_organic']
# y_30s = train_df['twodays_video_complete_views_30s_organic']
# y_complete = train_df['twodays_video_complete_views_organic']
y_10s = train_df['10s_bucket']
y_30s = train_df['30s_bucket']
y_complete = train_df['complete_views_bucket']

###generate DFs for analysis - X and Y
X = train_df[train_features]

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

accuracy_10s = []
error_10s = []
accuracy_30s = []
error_30s = []
accuracy_complete = []
error_complete = []

for train_index, test_index in kf.split(X):
    print("Fold = ", fold)
#     print("Shares: Fold = ", fold)
    y = y_10s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_10s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_10s.append(error_percent)
    
#     print("Clicks: Fold = ", fold)
    y = y_30s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_30s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_30s.append(error_percent)
    
    #     print("Clicks: Fold = ", fold)
    y = y_complete
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_complete.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_complete.append(error_percent)
    
    fold += 1
    
print("10s organic views performance: Accuracy = ", np.mean(accuracy_10s), " ; Error (/100) = ", np.mean(error_10s))
print("30s organic views performance: Accuracy = ", np.mean(accuracy_30s), " ; Error (/100) = ", np.mean(error_30s))
print("Complete organic views performance: Accuracy = ", np.mean(accuracy_complete), " ; Error (/100) = ", np.mean(error_complete))
# Out:
# TREE REGRESSION!
# No. of data-points =  5313
# Fold =  0
# Fold =  1
# Fold =  2
# Fold =  3
# Fold =  4
# Fold =  5
# Fold =  6
# Fold =  7
# Fold =  8
# Fold =  9
# 10s organic views performance: Accuracy =  0.844975913247  ; Error (/100) =  0.0377102909954
# 30s organic views performance: Accuracy =  0.853642302783  ; Error (/100) =  0.0394025918552
# Complete organic views performance: Accuracy =  0.833510074552  ; Error (/100) =  0.0425465193673

# %%
y_10s.hist(), y_30s.hist(), y_complete.hist()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1215642e8>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x1215642e8>)

# %%
import seaborn as sns
sns.set(color_codes = True)
sns.distplot(train_df['10s_bucket'])
# sns.distplot(y_10s)
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# sns.distplot(y_complete)
sns.distplot(train_df['30s_bucket'])
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(train_df['complete_views_bucket'])
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(train_df['twodays_video_views_10s_organic'])
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(train_df['twodays_video_complete_views_30s_organic'])
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(train_df['twodays_video_complete_views_organic'])
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
tf = pd.DataFrame()
for item in df['platform_objects']:
    print(1)
    pd.concat([tf, pd.DataFrame(item)])

# %%
train[train['unique_video_id'] == 21091]
# Out:
#                            external_id                  created_at  \
# 3373  377382845617050_1582794205075902  2017-06-05T23:00:18.401882
# 4569  571035253040893_1145476488930097  2017-06-05T16:01:04.156210
#
#           display_page                start_stats_date  \
# 3373  BuzzFeed Animals  2017-06-05 23:05:06.000000 UTC
# 4569              SOML  2017-06-05 16:05:08.000000 UTC
#
#                 firsthour_stats_date  \
# 3373  2017-06-06 00:05:10.000000 UTC
# 4569  2017-06-05 17:05:07.000000 UTC
#
#       firsthour_consumptions_by_type__link_clicks  \
# 3373                                     3.218876
# 4569                                     3.970292
#
#       firsthour_stories_by_action_type__share  \
# 3373                                 5.631212
# 4569                                 5.283204
#
#       firsthour_video_views_10s_organic  \
# 3373                           9.746073
# 4569                           9.943525
#
# ...

# %%
X = '377382845617050_1582794205075902'
query = 'facebook__' + X.split('_')[1]
params = {'platform_ids.external_id': query, 'page_size': 500}
resp = requests.get(url, headers = headers, params = params).json().get('results',[])

# %%
temp = pd.DataFrame(resp)
tf = pd.DataFrame()
for item in temp['platform_objects']:
    tp = pd.DataFrame(item)
    tf = pd.concat([tf,tp])

# %%
tf[['account_display_name', 'external_id']]
# Out:
#   account_display_name                       external_id
# 0     BuzzFeed Animals  377382845617050_1582794205075902
# 1                 SOML  571035253040893_1145476488930097
# 2             BuzzFeed     21898300328_10156178353820329

# %%
train_df[train_features]
# Out:
#       firsthour_consumptions_by_type__link_clicks  \
# 3821                                     3.912023
# 6399                                     0.693147
# 3814                                     1.609438
# 3822                                     1.791759
# 6404                                     1.098612
# 3817                                     5.030438
# 3816                                     5.594711
# 6400                                     3.713572
# 6401                                     1.945910
# 3812                                     1.098612
# 3824                                     0.000000
# 6393                                     4.430817
# 6407                                     3.583519
# 3823                                     5.099866
# 6397                                     2.302585
# 6402                                     0.000000
# 6396                                     1.098612
# 6406                                     4.290459
# ...

# %%
train_df['external_id'].shape, train_df['external_id'].unique().shape
# Out:
# ((7163,), (7163,))

# %%
train[~(train['unique_video_id'] == -1)].shape
# Out:
# (48, 17)

# %%
###Omnisearch API call -
lis = ['1614251518827491_1880685115517462']
# lis = ['1457722161221362_1848229595503948', '697789576948199_1492155130844969', '210885442609900_443332176031891']#, '1614251518827491_10210594664486324']
for X in lis:
    query = 'facebook__' + X.split('_')[1]
    params = {'platform_ids': query, 'page_size': 1}
    resp = requests.get(url, headers = headers, params = params).json().get('results',[])
    if resp == []:
        print("External ID: ", X, " ;  Unique content ID: EMPTY")
    else:
        df = pd.DataFrame(resp)
        print("External ID: ", X, " ;  Unique content ID:", df['_content_id'].values[0])

# OUTPUT:      
# External ID:  1457722161221362_1848229595503948  ;  Unique content ID: EMPTY
# External ID:  697789576948199_1492155130844969  ;  Unique content ID: 21259
# External ID:  210885442609900_443332176031891  ;  Unique content ID: 15745
# External ID:  1614251518827491_10210594664486324  ;  Unique content ID: EMPTY
# Out:
# External ID:  1614251518827491_1880685115517462  ;  Unique content ID: 11845

# %%
# for item in df['platform_objects']:
#     print(item, "!"
resp
# Out:
# [{'_content_id': 11845,
#   '_content_source': 'video',
#   'aspect_ratio': '',
#   'created_at': 1486055863,
#   'created_by_id': 434,
#   'credits': [{'_document_source': 'video',
#     '_document_source_id': 24987,
#     'email': 'katie.melody@buzzfeed.com',
#     'name': 'Katie Melody',
#     'source': 'BuzzFeed',
#     'type': 'Cast',
#     'user_id': 1670},
#    {'_document_source': 'video',
#     '_document_source_id': 24988,
#     'email': 'hector.gomez@buzzfeed.com',
#     'name': 'Hector Gomez',
#     'source': 'BuzzFeed',
#     'type': 'Lead Producer',
#     'user_id': 434},
#    {'_document_source': 'video',
#     '_document_source_id': 24989,
#     'email': '',
#     'name': '',
#     'source': 'Warner Chappell',
#     'type': 'Audio',
#     'user_id': None}],
#   'description': '',
#   'doc_type': 'video',
#   'duration': 49,
#   'is_branded': False,
#   'is_variant': False,
#   'keywords': '',
#   'language': 'eng',
#   'live_at': 1487979011,
# ...

# %%
hits = 0
total = 0
content_id = []
title = []
external_id = []

for X in train_df['external_id']:
    total += 1
    query = 'facebook__' + X.split('_')[1]
    if query == "":
        ###what if there is only 1 part to the external ID of the video
        query = X
        
    params = {'platform_ids': query, 'page_size': 1}
    external_id.append(X)
    
    try:
        resp = requests.get(url, headers = headers, params = params).json().get('results',[])
    except:
        resp = []

    if resp == []:
        print("External ID: ", X, " ;  Unique content ID: EMPTY")
        content_id.append(-1)
        title.append("")
    else:
        df = pd.DataFrame(resp)
        print("External ID: ", X, " ;  Unique content ID:", df['_content_id'].values[0])
        hits += 1
        content_id.append(df['_content_id'].values[0])
        title.append(df['title'].values[0])
    
    if (total % 100 == 0):
        print("Hits: ", hits, " ; Total: ", total)
    ###1 request per second - sleep to respect rate limit!
    time.sleep(1)
    
print("Hits: ", hits, " ; Total: ", total)
train_df['content_id'] = content_id
train_df['title'] = title

print("DONE!")

#started at ~ 4:10 PM - Jun 9
# Out:
# External ID:  697789576948199_1492155130844969  ;  Unique content ID: 21259
# External ID:  377382845617050_1582812658407390  ;  Unique content ID: EMPTY
# External ID:  666255463425866_1567072550010815  ;  Unique content ID: EMPTY
# External ID:  210885442609900_443332176031891  ;  Unique content ID: 15745
# External ID:  509565169222978_10209489846266967  ;  Unique content ID: EMPTY
# External ID:  1679616822293043_1851556861524969  ;  Unique content ID: EMPTY
# External ID:  1433294486996353_1890805084578622  ;  Unique content ID: EMPTY
# External ID:  1412984988933193_2020285288203157  ;  Unique content ID: EMPTY
# External ID:  200954443595756_441618726195992  ;  Unique content ID: 21257
# External ID:  1633535693574047_1775357096058572  ;  Unique content ID: EMPTY
# External ID:  697789576948199_1491945867532562  ;  Unique content ID: EMPTY
# External ID:  666255463425866_1561559313895472  ;  Unique content ID: EMPTY
# ...

# %%
train_df.to_csv('video_stats_with_content_id.csv', index = False)

# %%
print("There's gonna be a repeat between elements 1029 - 1031 since - External ID:  546839862037459_1395762787145158  ;  Unique content ID: 18253 was queried twice!")

# %%
hits, total, hits/total
# Out:
# (3389, 7163, 0.4731257852854949)

# %%
len(title), len(content_id), len(train_df['external_id'])
# Out:
# (7163, 7163, 7163)

# %%
reps_2 = 0
reps_3 = 0
reps_4 = 0
reps_5 = 0

for video in train_df['content_id'].unique():
    if video == -1:
        continue
        
    temp = train_df[train_df['content_id'] == video]
    if len(temp) >= 2:
        reps_2 += 1
    if len(temp) >= 3:
        reps_3 += 1
    if len(temp) >= 4:
        reps_4 += 1
    if len(temp) >= 5:
        reps_5 += 1

print("Reps 2, 3, 4, 5 = ", reps_2, reps_3, reps_4, reps_5)
# Out:
# Reps 2, 3, 4, 5 =  195 23 1 0

# %%
train_df['display_page'].unique().shape, train_df[~(train_df['content_id'] == -1)]['display_page'].unique().shape,
# Out:
# ((110,), (84,))

# %%
hits = 0
total = 0
content_id = []
title = []
external_id = []

for X in train_df['external_id']:
    try:
        query = 'facebook__' + X.split('_')[1]
    except:
        query = X
    total += 1
     
    params = {'platform_ids': query, 'page_size': 1}
    external_id.append(X)

    try:
        resp = requests.get(url, headers = headers, params = params).json().get('results',[])
    except:
        resp = []

    if resp == []:
        print("External ID: ", X, " ;  Unique content ID: EMPTY")
        content_id.append(-1)
        title.append("")
    else:
        df = pd.DataFrame(resp)
        print("External ID: ", X, " ;  Unique content ID:", df['_content_id'].values[0])
        hits += 1
        content_id.append(df['_content_id'].values[0])
        title.append(df['title'].values[0])
    
    if (total % 100 == 0):
        print("Hits: ", hits, " ; Total: ", total)
    ###1 request per second - sleep to respect rate limit!
    time.sleep(1)
    
print("Hits: ", hits, " ; Total: ", total)
train_df['content_id'] = content_id
train_df['title'] = title

print("DONE!")
#started at ~ 4:10 PM - Jun 9
# Out:
# External ID:  1412984988933193_2020296224868730  ;  Unique content ID: EMPTY
# External ID:  697789576948199_1492155130844969  ;  Unique content ID: 21259
# External ID:  377382845617050_1582812658407390  ;  Unique content ID: EMPTY
# External ID:  666255463425866_1567072550010815  ;  Unique content ID: EMPTY
# External ID:  1457722161221362_1848229595503948  ;  Unique content ID: EMPTY
# External ID:  210885442609900_443332176031891  ;  Unique content ID: 15745
# External ID:  1614251518827491_1844845075529481  ;  Unique content ID: EMPTY
# External ID:  509565169222978_10209489846266967  ;  Unique content ID: EMPTY
# External ID:  1679616822293043_1851556861524969  ;  Unique content ID: EMPTY
# External ID:  1614251518827491_10210594664486324  ;  Unique content ID: EMPTY
# External ID:  1433294486996353_1890805084578622  ;  Unique content ID: EMPTY
# External ID:  1412984988933193_2020285288203157  ;  Unique content ID: EMPTY
# ...

# %%
train_df.to_csv('video_stats_with_content_id.csv', index = None)

# %%
train_df.columns
# Out:
# Index(['external_id', 'created_at', 'display_page', 'start_stats_date',
#        'firsthour_stats_date', 'firsthour_consumptions_by_type__link_clicks',
#        'firsthour_stories_by_action_type__share',
#        'firsthour_video_views_10s_organic',
#        'firsthour_video_complete_views_30s_organic',
#        'firsthour_video_complete_views_organic', 'twodays_stats_date',
#        'twodays_consumptions_by_type__link_clicks',
#        'twodays_stories_by_action_type__share',
#        'twodays_video_views_10s_organic',
#        'twodays_video_complete_views_30s_organic',
#        'twodays_video_complete_views_organic', '10s_bucket', '30s_bucket',
#        'complete_views_bucket'],
#       dtype='object')

# %%
train_df
# Out:
#                              external_id                  created_at  \
# 3821   1412984988933193_2020296224868730  2017-06-06T13:45:21.211324
# 6399    697789576948199_1492155130844969  2017-06-06T13:30:29.693824
# 3814    377382845617050_1582812658407390  2017-06-06T13:01:13.638430
# 3822    666255463425866_1567072550010815  2017-06-06T12:30:11.651925
# 6404   1457722161221362_1848229595503948  2017-06-06T12:00:06.223092
# 3817     210885442609900_443332176031891  2017-06-06T12:02:18.623778
# 3816   1614251518827491_1844845075529481  2017-06-06T11:00:48.492900
# 6400   509565169222978_10209489846266967  2017-06-06T11:00:48.035436
# 6401   1679616822293043_1851556861524969  2017-06-06T11:01:31.245525
# 3812  1614251518827491_10210594664486324  2017-06-06T11:01:30.651996
# 3824   1433294486996353_1890805084578622  2017-06-06T10:31:08.114664
# 6393   1412984988933193_2020285288203157  2017-06-06T10:15:11.825488
# 6407     200954443595756_441618726195992  2017-06-06T09:18:03.186296
# ...

# %%
3389/7163
# Out:
# 0.4731257852854949

# %%
temp_df = pd.read_csv('jan_to_jun_2017_videos_type_2_16')
temp_df = temp_df.fillna(0)

print(temp_df.shape)

# video_df.shape, video_df['external_id'].unique().shape
temp_df = temp_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')
print(temp_df.shape)
# Out:
# (16429, 17)
# (10871, 17)

# %%
###FORECASTING - TASK 0 (Given performance of a video on a FB page within 1st hour, predict its performance in 2 days!)
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

train = temp_df
features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
features = ['firsthour_' + var for var in features]

features.append('post_type_id')

# for feat in features:
#     train[feat] = np.log(train[feat] + 1)

####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

print("twodays_video_views_10s_organic!")
# res = ols(y = np.log(train['twodays_video_views_10s_organic']+1), x = train[features])
res = ols(y = train['twodays_video_views_10s_organic'], x = train[features])
print(res)

print("twodays_video_complete_views_30s_organic!")
# res = ols(y = np.log(train['twodays_video_complete_views_30s_organic']+1), x = train[features])
res = ols(y = train['twodays_video_complete_views_30s_organic'], x = train[features])
print(res)


print("twodays_video_complete_views_organic!")
res = ols(y = train['twodays_video_complete_views_organic'], x = train[features])
# res = ols(y = np.log(train['twodays_video_complete_views_organic']+1), x = train[features])
print(res)
# Out:
# twodays_video_views_10s_organic!
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <firsthour_consumptions_by_type__link_clicks>
#              + <firsthour_stories_by_action_type__share> + <firsthour_video_views_10s_organic>
#              + <firsthour_video_complete_views_30s_organic>
#              + <firsthour_video_complete_views_organic> + <post_type_id> + <intercept>
#
# Number of Observations:         10871
# Number of Degrees of Freedom:   7
#
# R-squared:         0.2458
# Adj R-squared:     0.2454
#
# Rmse:          1596235.1894
#
# F-stat (6, 10864):   590.1283, p-value:     0.0000
#
# Degrees of Freedom: model 6, resid 10864
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ...

# %%
##given performance in the previous page, where should I post next?
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.cross_validation import train_test_split
import math

from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# from sklearn import linear_model
# clf = linear_model.LinearRegression()
# print("LINEAR REGRESSION!")

from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth=10)
print("TREE REGRESSION!")


train_df = pd.read_csv('jan_to_jun_2017_videos_type_2_16')
train_df = train_df.fillna(0)

# video_df.shape, video_df['external_id'].unique().shape
train_df = train_df.sort_values('firsthour_stats_date', ascending = False).drop_duplicates(subset=['external_id'], keep = 'last')

post_type = ['post_type_id']
one_hour_features = [
                'consumptions_by_type__link_clicks',
                'stories_by_action_type__share',
                'video_views_10s_organic',
                'video_complete_views_30s_organic',
                'video_complete_views_organic',
               ]
one_hour_features = ['firsthour_' + var for var in one_hour_features]

# train_features = one_hour_features
train_features = one_hour_features + post_type

# for feats in (one_hour_features):
#     train_df[feats] = np.log(train_df[feats] + 1)

# lm = linear_model.LinearRegression(fit_intercept=True, normalize=True)
cv = 10

# train_df['10s_bucket'] = np.log(train_df['twodays_video_views_10s_organic'] + 1).astype(int)
# train_df['30s_bucket'] = np.log(train_df['twodays_video_complete_views_30s_organic'] + 1).astype(int)
# train_df['complete_views_bucket'] = np.log(train_df['twodays_video_complete_views_organic'] + 1).astype(int)

print("No. of data-points = ", len(train_df))

y_10s = train_df['twodays_video_views_10s_organic']
y_30s = train_df['twodays_video_complete_views_30s_organic']
y_complete = train_df['twodays_video_complete_views_organic']
# y_10s = train_df['10s_bucket']
# y_30s = train_df['30s_bucket']
# y_complete = train_df['complete_views_bucket']

###generate DFs for analysis - X and Y
X = train_df[train_features]

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

accuracy_10s = []
error_10s = []
accuracy_30s = []
error_30s = []
accuracy_complete = []
error_complete = []

for train_index, test_index in kf.split(X):
    print("Fold = ", fold)
#     print("Shares: Fold = ", fold)
    y = y_10s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_10s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_10s.append(error_percent)
    
#     print("Clicks: Fold = ", fold)
    y = y_30s
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_30s.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_30s.append(error_percent)
    
    #     print("Clicks: Fold = ", fold)
    y = y_complete
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
#     print("Cross-Predicted Accuracy (R2):", accuracy)
    accuracy_complete.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
#     print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    error_complete.append(error_percent)
    
    fold += 1
    
print("10s organic views performance: Accuracy = ", np.mean(accuracy_10s), " ; Error (/100) = ", np.mean(error_10s))
print("30s organic views performance: Accuracy = ", np.mean(accuracy_30s), " ; Error (/100) = ", np.mean(error_30s))
print("Complete organic views performance: Accuracy = ", np.mean(accuracy_complete), " ; Error (/100) = ", np.mean(error_complete))
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# TREE REGRESSION!
# No. of data-points =  10871
# Fold =  0
# Fold =  1
# Fold =  2
# Fold =  3
# Fold =  4
# Fold =  5
# Fold =  6
# Fold =  7
# Fold =  8
# Fold =  9
# 10s organic views performance: Accuracy =  0.882049715598  ; Error (/100) =  0.326429628455
# 30s organic views performance: Accuracy =  0.898455036946  ; Error (/100) =  0.294533763006
# Complete organic views performance: Accuracy =  0.865497576492  ; Error (/100) =  0.330013399094

# %%
import time
import requests

url = 'https://api-public.buzzfeed.com/omnisearch/search/videos'
# url = 'https://api.buzzfeed.com/omnisearch/search/videos/'
headers = { 'X-Auth-Token': 'ef2a7012-835f-4b5a-b527-22be59815e10'}

hits = 0
total = 0
content_id = []
title = []
external_id = []

for X in train_df['external_id']:
    try:
        query = 'facebook__' + X.split('_')[1]
    except:
        query = X
    total += 1
     
    params = {'platform_ids': query, 'page_size': 1, 'unfiltered': True}
    external_id.append(X)

    try:
        resp = requests.get(url, headers = headers, params = params).json().get('results',[])
    except:
        resp = []

    ###verify that the response has a content ID for the video
    try:
        df = pd.DataFrame(resp)
        temp = df['_content_id'].values[0]
    except:
        resp = []
    
    if resp == []:
        print("External ID: ", X, " ;  Unique content ID: EMPTY")
        content_id.append(-1)
        title.append("")
    else:
        df = pd.DataFrame(resp)
        print("External ID: ", X, " ;  Unique content ID:", df['_content_id'].values[0])
        hits += 1
        content_id.append(df['_content_id'].values[0])
        title.append(df['title'].values[0])
    
    if (total % 100 == 0):
        print("Hits: ", hits, " ; Total: ", total)
    ###1 request per second - sleep to respect rate limit!
    time.sleep(1)
    
print("Hits: ", hits, " ; Total: ", total)
train_df['content_id'] = content_id
train_df['title'] = title
train_df['validation_external_id'] = external_id

train_df.to_csv('jan-jun-2017-videos-post-type-2-16.csv', index = None)
print("DONE!")
#started at ~ 4:10 PM - Jun 9
# Out:
# External ID:  1318800798260799_2240508729423330  ;  Unique content ID: 15791
# External ID:  509565169222978_726756550837171  ;  Unique content ID: 18005
# External ID:  375093055847509_1482596015097202  ;  Unique content ID: 19141
# External ID:  1272480059489124_1643574589046334  ;  Unique content ID: 17620
# External ID:  195989344211258_253832761760249  ;  Unique content ID: 19111
# External ID:  537452496455998_676994869168426  ;  Unique content ID: EMPTY
# External ID:  1466985283336295_1630963833605105  ;  Unique content ID: 15367
# External ID:  1318800798260799_2240454366095433  ;  Unique content ID: 21306
# External ID:  1679616822293043_1888986744689382  ;  Unique content ID: 19118
# External ID:  21898300328_10156211274535329  ;  Unique content ID: EMPTY
# External ID:  458142997564706_1406850289360634  ;  Unique content ID: EMPTY
# External ID:  697789576948199_1499596343434181  ;  Unique content ID: 21571
# ...

# %%
### Example misses: 
#375093055847509_1343679085655563
#571035253040893_1133572946787118
#1415259028748073_1858180304433948
hits/total
# Out:
# 0.509244779689081

# %%
train_df[(train_df['post_type_id'] == 2) & ~(train_df['content_id'] == -1)].mean()#['twodays_stories_by_action_type__share'].mean()
# Out:
# post_type_id                                   2.000000e+00
# firsthour_consumptions_by_type__link_clicks    4.963558e+02
# firsthour_stories_by_action_type__share        1.888906e+03
# firsthour_video_views_10s_organic              1.234277e+05
# firsthour_video_complete_views_30s_organic     8.780946e+04
# firsthour_video_complete_views_organic         4.386593e+04
# twodays_consumptions_by_type__link_clicks      3.805930e+03
# twodays_stories_by_action_type__share          2.072317e+04
# twodays_video_views_10s_organic                1.150814e+06
# twodays_video_complete_views_30s_organic       8.379379e+05
# twodays_video_complete_views_organic           4.420697e+05
# content_id                                     2.977943e+04
# dtype: float64

# %%
train_df[(train_df['post_type_id'] == 16) & ~(train_df['content_id'] == -1)].mean()#['twodays_stories_by_action_type__share'].mean()
# Out:
# post_type_id                                       16.000000
# firsthour_consumptions_by_type__link_clicks       545.583759
# firsthour_stories_by_action_type__share             0.508172
# firsthour_video_views_10s_organic              138846.083248
# firsthour_video_complete_views_30s_organic      97118.199183
# firsthour_video_complete_views_organic          50399.998468
# twodays_consumptions_by_type__link_clicks        3376.177222
# twodays_stories_by_action_type__share               2.448417
# twodays_video_views_10s_organic                676268.019408
# twodays_video_complete_views_30s_organic       481362.012768
# twodays_video_complete_views_organic           251905.972932
# content_id                                      25144.777835
# dtype: float64

# %%
train_df.groupby('content_id').count()
# Out:
#             external_id  post_type_id  created_at  display_page  \
# content_id
# -1                 5335          5335        5335          5335
#  74                   1             1           1             1
#  132                  2             2           2             2
#  135                  2             2           2             2
#  275                  1             1           1             1
#  302                  1             1           1             1
#  525                  1             1           1             1
#  583                  1             1           1             1
#  779                  2             2           2             2
#  831                  2             2           2             2
#  849                  2             2           2             2
#  1193                 1             1           1             1
#  1200                 2             2           2             2
# ...
