# %%
###fit the regression 
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline

filepath = "/Users/eshwarchandrasekharan/Desktop/buzzed_code/"
pages = ['BuzzFeed Books', 'Tasty', 'BuzzFeed España', 'BuzzFeed Scotland', 'SOML', 'BuzzFeed News BR', 'Proper Tasty', 'BuzzFeed News','Obsessed by BuzzFeed', 'BuzzFeed France', 'BuzzFeed', 'BuzzFeed World', 'BuzzFeed Australia', 'LOLA','BuzzFeed Style','Top Knot',]
# page_info = pd.read_csv('datapoints/data-points-Tasty.csv')

for page in pages:
    print("WORKING ON FB PAGE: ",page)
    page_info = pd.read_csv(filepath+'datapoints/data-points-'+ page + '.csv')
    
    if len(page_info) < 10:
        print("NEED MORE DATA - SKIPPING PAGE!")
        continue
        
    ###generate DFs for analysis - X and Y
    df = page_info.drop(['24_hours_clicks', '24_hours_share', 'within_30_mins', 'within_24_hours', 'stats_ts','stats_date', 'external_id'], 1)
    y_share = page_info['24_hours_share']
    y_clicks = page_info['24_hours_clicks']

    ###TESTING FOR SHARE - SAMPLE
    # create training and testing vars

    metric = 'share'
    # metric = 'clicks'

    if metric == 'share':
        y = y_share
        print("Testing for shares!")
    else:
        y = y_clicks
        print("Testing for clicks!")

    X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
#     print(X_train.shape, y_train.shape)
#     print(X_test.shape, y_test.shape)

    # fit a model
    lm = linear_model.LinearRegression()
    model = lm.fit(X_train, y_train)
    predictions = lm.predict(X_test)
#     predictions[0:10]
    print("Coefficients: ", lm.coef_)

    ## The line / model
    plt.scatter(y_test, predictions)
    plt.xlabel("True Values")
    plt.ylabel("Predictions")
    plt.show()

#     print("Trial run - Score:", model.score(X_test, y_test))

    ###prediction with cross validation
    # Necessary imports: 
    from sklearn.cross_validation import cross_val_score, cross_val_predict
    from sklearn import metrics

    # 10-fold CV
    scores = cross_val_score(model, df, y, cv = 10)
    print("Cross-validated scores:", scores)
    print("Mean score = ", scores.mean())


    # Make cross validated predictions
    predictions = cross_val_predict(model, df, y, cv=10)
    plt.scatter(y, predictions)

    accuracy = metrics.r2_score(y, predictions)
    print("( ", metric, " on FB/", page," ) Cross-Predicted Accuracy (R2): ", accuracy)
    
    ###TESTING FOR CLICKS - SAMPLE
    # create training and testing vars

    # metric = 'share'
    metric = 'clicks'

    if metric == 'share':
        y = y_share
        print("Testing for shares!")
    else:
        y = y_clicks
        print("Testing for clicks!")

    X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
#     print(X_train.shape, y_train.shape)
#     print(X_test.shape, y_test.shape)

    # fit a model
    lm = linear_model.LinearRegression()
    model = lm.fit(X_train, y_train)
    predictions = lm.predict(X_test)
    print("Coefficients: ", lm.coef_)
#     predictions[0:10]


    ## The line / model
    plt.scatter(y_test, predictions)
    plt.xlabel("True Values")
    plt.ylabel("Predictions")
    plt.show()

#     print("Trial run - Score:", model.score(X_test, y_test))

    ###prediction with cross validation
    # Necessary imports: 
    from sklearn.cross_validation import cross_val_score, cross_val_predict
    from sklearn import metrics

    # 10-fold CV
    scores = cross_val_score(model, df, y, cv = 10)
    print("Cross-validated scores:", scores)
    print("Mean score = ", scores.mean())

    # Make cross validated predictions
    predictions = cross_val_predict(model, df, y, cv=10)
    plt.scatter(y, predictions)

    accuracy = metrics.r2_score(y, predictions)
    print("( ", metric, " on FB/", page," ) Cross-Predicted Accuracy (R2): ", accuracy)
# Out:
# WORKING ON FB PAGE:  BuzzFeed Books
# Testing for shares!
# Coefficients:  [  1.45039056e-01   4.50559908e-02  -5.18507632e-01   1.45402120e+00
#    4.82447026e-01   9.65809951e+00  -1.38501492e-01   4.89866532e-02
#   -3.85082025e-02  -6.32999088e-04]
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Cross-validated scores: [ 0.84030525  0.86008734  0.77662237  0.82314468  0.91207446  0.88514161
#   0.64892428  0.77572296  0.71863913  0.6887461 ]
# Mean score =  0.792940816801
# (  share  on FB/ BuzzFeed Books  ) Cross-Predicted Accuracy (R2):  0.773200942509
# Testing for clicks!
# Coefficients:  [ 16.65558234   5.2217196  -26.8770414   -0.71529656  29.76873841
#   34.70452788  -6.71765924   0.68620449  -0.46515147  -0.22693801]
# Cross-validated scores: [ 0.85880429  0.89315583  0.78868921  0.92513175  0.82111053  0.90541631
#   0.89697209  0.76624369  0.84987968  0.88224841]
# Mean score =  0.858765178398
# (  clicks  on FB/ BuzzFeed Books  ) Cross-Predicted Accuracy (R2):  0.865799474936
# WORKING ON FB PAGE:  Tasty
# Testing for shares!
# Coefficients:  [  2.04131203e-02   4.08480253e-02   9.23353385e-01  -1.66290553e+00
#   -6.01680542e-01   8.73160065e+00  -9.95715179e-03   5.58240675e-04
#    1.21095815e-03  -2.11189390e-03]
# Cross-validated scores: [ 0.8899552   0.91378831  0.95155401  0.88587699  0.82907928  0.8201127
#   0.94755223  0.97400754  0.85335569  0.77727153]
# Mean score =  0.884255349013
# (  share  on FB/ Tasty  ) Cross-Predicted Accuracy (R2):  0.914539008975
# Testing for clicks!
# Coefficients:  [  12.02839412    1.95303265  -75.56181854  -30.47575375  105.99340171
#    13.45193119   -4.16663985    0.31307628    0.13908135   -0.45547467]
# Cross-validated scores: [ 0.82749929  0.85323014  0.84030388  0.71519913  0.82544176  0.78195891
#   0.77699426  0.92399787  0.43682741  0.6999772 ]
# Mean score =  0.768142984371
# (  clicks  on FB/ Tasty  ) Cross-Predicted Accuracy (R2):  0.793194322121
# WORKING ON FB PAGE:  BuzzFeed España
# Testing for shares!
# Coefficients:  [  2.04978499e+00   1.17059715e+00   1.70589544e+00   1.15780943e-01
#    1.40711955e+00   1.01326780e+01  -2.08027117e+00   4.59940391e-02
#    9.27557424e-03  -6.67760109e-02]
# Cross-validated scores: [ 0.45936518  0.6881206   0.34156291  0.84065108  0.01367001  0.77343998
#   0.71890583  0.77834315  0.85097026  0.29495578]
# Mean score =  0.575998478202
# (  share  on FB/ BuzzFeed España  ) Cross-Predicted Accuracy (R2):  0.638238505751
# Testing for clicks!
# Coefficients:  [ 46.66155422  10.7849968    3.13990769  45.40805095  49.44069371
#   44.17019961 -40.04236879   2.07218282  -1.41151665  -0.4271428 ]
# Cross-validated scores: [ 0.58317636  0.60564507  0.83938116  0.7902895   0.63122967  0.72935085
#   0.64309815  0.91539255  0.85531821 -0.43121006]
# Mean score =  0.616167145321
# (  clicks  on FB/ BuzzFeed España  ) Cross-Predicted Accuracy (R2):  0.672658410654
# WORKING ON FB PAGE:  BuzzFeed Scotland
# Testing for shares!
# Coefficients:  [ -1.85951286e-01  -4.57005001e-01  -2.72615318e+00   3.52295303e-01
#    2.29668495e+00   1.61909384e+01   2.72946903e-01   1.33785226e-02
#   -2.94986826e-02   1.96648559e-02]
# Cross-validated scores: [ 0.75368855  0.00971855  0.5449678   0.53024334  0.50065593  0.43105858
#   0.18877591  0.29329247 -1.1615665   0.43667769]
# Mean score =  0.252751231934
# (  share  on FB/ BuzzFeed Scotland  ) Cross-Predicted Accuracy (R2):  0.381278351131
# Testing for clicks!
# Coefficients:  [  8.06571620e+00  -3.40114733e+00  -9.89115507e+01   2.46818853e+00
#    8.90932744e+01   2.03952949e+02   2.26896194e+00   1.82409888e+00
#    1.55296239e-01  -2.30639397e+00]
# Cross-validated scores: [ 0.69944646  0.21674827  0.56997931  0.68437015  0.90965275  0.80262554
#   0.93630991  0.67600478  0.73989027  0.78567613]
# Mean score =  0.702070358231
# (  clicks  on FB/ BuzzFeed Scotland  ) Cross-Predicted Accuracy (R2):  0.815929063298
# WORKING ON FB PAGE:  SOML
# Testing for shares!
# Coefficients:  [  7.43823190e-02   3.52573832e-02   8.05146829e-01  -5.02828691e-01
#   -4.57915221e-01   8.69527941e+00  -6.00606971e-02   5.73891187e-03
#   -5.02460114e-03  -1.10987284e-03]
# Cross-validated scores: [ 0.73259699  0.89129628  0.96446564  0.69116737  0.89763882  0.97371073
#   0.95565962  0.71606985  0.89495806  0.87127441]
# Mean score =  0.858883778191
# (  share  on FB/ SOML  ) Cross-Predicted Accuracy (R2):  0.874674356109
# Testing for clicks!
# Coefficients:  [  5.81939696e+00  -1.28645351e+01  -2.05340987e+01   8.87712800e+01
#    1.83326803e+01   5.61691351e+01   7.14239218e+00   5.10635082e-01
#   -9.62758265e-03  -5.98346488e-01]
# Cross-validated scores: [ 0.54423422  0.90760217  0.88222198  0.92194879  0.93809983  0.93546525
#   0.84398864  0.8406454   0.78240514  0.92920741]
# Mean score =  0.852581882412
# (  clicks  on FB/ SOML  ) Cross-Predicted Accuracy (R2):  0.902524971853
# WORKING ON FB PAGE:  BuzzFeed News BR
# Testing for shares!
# Coefficients:  [ -1.10256301e+00   6.50493326e-01  -6.57277203e+00  -4.54757025e+01
#    3.75615563e+00   3.80025823e+01   6.38382043e+00   1.35814461e+00
#    1.80119496e-02  -1.37017860e+00]
# Cross-validated scores: [ -6.95668168e+00  -2.63234499e+01  -4.71179356e+00  -2.23833592e+02
#   -4.29148641e+00  -1.80105155e+00  -1.21394102e+00  -5.38051089e+01
#   -4.07798432e+01   6.39779760e-02]
# Mean score =  -36.3652970426
# (  share  on FB/ BuzzFeed News BR  ) Cross-Predicted Accuracy (R2):  -84.6028670893
# Testing for clicks!
# Coefficients:  [ -11.77652541   -3.92654085  -86.89374539 -255.64166803   49.38889585
#   195.379637    169.21177854   37.74896901    0.4850272   -37.91139172]
# Cross-validated scores: [ -4.38096021e-01  -5.23127646e+00  -1.37959688e+01  -4.80227062e+02
#   -1.46565662e+01  -1.85462471e+01  -4.20303826e-02   4.95863555e-01
#   -3.21026990e+00   2.17674414e-01]
# Mean score =  -53.5433979094
# (  clicks  on FB/ BuzzFeed News BR  ) Cross-Predicted Accuracy (R2):  -89.8413642378
# WORKING ON FB PAGE:  Proper Tasty
# NEED MORE DATA - SKIPPING PAGE!
# WORKING ON FB PAGE:  BuzzFeed News
# Testing for shares!
# Coefficients:  [ -1.05276799e-01  -2.28258953e-01  -1.66762440e-01   1.66656857e+00
#    2.26587059e-01   6.96541779e+00   1.96240637e-01   5.31939196e-03
#   -2.37590929e-02   1.70904123e-02]
# Cross-validated scores: [ 0.48810005  0.81214338  0.7523219   0.72469835  0.67318159  0.7198444
#   0.8600538   0.5964313   0.80495496  0.81277329]
# Mean score =  0.724450302408
# (  share  on FB/ BuzzFeed News  ) Cross-Predicted Accuracy (R2):  0.738342857284
# Testing for clicks!
# Coefficients:  [  6.19001868  -4.77439778  -3.87968351  23.01047601   6.87486074
#   27.02820872   4.85203456   0.13746059  -0.70566869   0.50747002]
# Cross-validated scores: [ 0.77104922  0.83578424  0.85825139  0.79617035  0.72520631  0.77578038
#   0.89464516  0.79997905  0.79188859  0.74678471]
# Mean score =  0.79955393859
# (  clicks  on FB/ BuzzFeed News  ) Cross-Predicted Accuracy (R2):  0.798160650324
# WORKING ON FB PAGE:  Obsessed by BuzzFeed
# Testing for shares!
# Coefficients:  [ -6.74356613e-03  -6.50230644e-02   7.41160728e-01   4.36244031e-01
#    1.10483636e-01   3.94802081e+00   4.18968752e-02  -1.55389779e-03
#   -5.03118576e-03   2.82415427e-04]
# Cross-validated scores: [ 0.4327927   0.66670911  0.52415882  0.58214522  0.6498245   0.39295037
#   0.45375265 -0.47012394  0.75300019  0.28526027]
# Mean score =  0.427046986961
# (  share  on FB/ Obsessed by BuzzFeed  ) Cross-Predicted Accuracy (R2):  0.627418545066
# Testing for clicks!
# Coefficients:  [  1.74694364e+00  -2.93121624e+00  -4.23284879e+01   2.26221692e+01
#    2.95163177e+01   2.08018578e+01   6.01244856e+00   1.28647429e-01
#    1.35915481e-02  -1.93236998e-01]
# Cross-validated scores: [ 0.40138627 -0.52779118  0.55865977  0.60848757  0.76025966  0.22577207
#   0.53866647  0.40088243  0.45916952  0.60833739]
# Mean score =  0.403382996721
# (  clicks  on FB/ Obsessed by BuzzFeed  ) Cross-Predicted Accuracy (R2):  0.480826997583
# WORKING ON FB PAGE:  BuzzFeed France
# Testing for shares!
# Coefficients:  [ -5.77037206e-02  -2.58828736e-01  -1.18392770e+00   1.63408985e+00
#    8.73829087e-01   1.65305884e+01   1.02512335e-01   1.41692926e-02
#   -6.07285719e-03  -7.06978014e-03]
# Cross-validated scores: [ 0.59401087  0.87106572  0.42487103 -1.3626727   0.49833606  0.42813473
#   0.70100695  0.5744031   0.54393184 -1.34135496]
# Mean score =  0.193173264271
# (  share  on FB/ BuzzFeed France  ) Cross-Predicted Accuracy (R2):  0.572475670267
# Testing for clicks!
# Coefficients:  [   9.27073235  -13.82785936  244.95527306  148.12059723 -164.49771834
#   264.18711521    7.76608544    1.71791237   -0.27769735   -1.66795741]
# Cross-validated scores: [ 0.67490871  0.80419188  0.73612117 -0.14183824  0.55578306  0.00972115
#   0.56148664  0.49348778  0.90257368  0.78544535]
# Mean score =  0.538188116428
# (  clicks  on FB/ BuzzFeed France  ) Cross-Predicted Accuracy (R2):  0.798321804509
# WORKING ON FB PAGE:  BuzzFeed
# Testing for shares!
# Coefficients:  [-0.02839851 -0.03805907  0.27762707  0.18659796 -0.0898205   7.76790988
#   0.05675491  0.01252608 -0.02054322  0.00938969]
# Cross-validated scores: [ 0.47756714  0.89149736  0.86660964  0.80076242  0.90178375  0.84400486
#   0.87151062  0.85616451  0.68395383  0.84488332]
# Mean score =  0.803873746277
# (  share  on FB/ BuzzFeed  ) Cross-Predicted Accuracy (R2):  0.818280126518
# Testing for clicks!
# Coefficients:  [  7.0649994   -1.37482084   2.78238465   8.085981     6.23889253
#   78.22255985   1.34799904   0.82504505  -0.94250775   0.16630832]
# Cross-validated scores: [ 0.8457988   0.7826422   0.85082598  0.85495344  0.84632599  0.87574471
#   0.90187421  0.78702214  0.8377132   0.82410537]
# Mean score =  0.840700603849
# (  clicks  on FB/ BuzzFeed  ) Cross-Predicted Accuracy (R2):  0.843030528329
# WORKING ON FB PAGE:  BuzzFeed World
# Testing for shares!
# Coefficients:  [-0.38966493 -0.84389526 -1.1851179  -1.4946837   0.52700571  4.35329433
#   0.65740853  0.01449546  0.01935509 -0.02731485]
# Cross-validated scores: [ 0.75787528  0.82673583  0.7713319   0.44273241  0.3640444   0.30168236
#   0.0857517   0.91317609  0.4129426   0.86099575]
# Mean score =  0.573726831379
# (  share  on FB/ BuzzFeed World  ) Cross-Predicted Accuracy (R2):  0.500727491708
# Testing for clicks!
# Coefficients:  [ 19.85122904  -3.28497895 -16.58957395  -8.87515687  19.07505711
#  -25.42412444  -5.98629881   1.10003192   0.67269155  -1.61387419]
# Cross-validated scores: [ 0.70408835  0.89544125  0.8639412   0.67070648  0.69347644  0.18700093
#   0.80491263  0.90343604  0.84345061  0.86410431]
# Mean score =  0.743055824262
# (  clicks  on FB/ BuzzFeed World  ) Cross-Predicted Accuracy (R2):  0.524541397078
# WORKING ON FB PAGE:  BuzzFeed Australia
# Testing for shares!
# Coefficients:  [  6.07474593e-02   2.18743818e-02   1.03710924e-01  -7.42996912e-02
#   -2.99102039e-05   1.14961199e+01  -4.65400564e-02   3.28437806e-03
#   -5.76849069e-03   1.42628102e-03]
# Cross-validated scores: [ 0.49077825 -4.23211957  0.6139115   0.74614377  0.5596177   0.81282845
#   0.69217851  0.76107635  0.59470175  0.73912999]
# Mean score =  0.177824668812
# (  share  on FB/ BuzzFeed Australia  ) Cross-Predicted Accuracy (R2):  0.368650253317
# Testing for clicks!
# Coefficients:  [  5.38071267e+00  -3.65038563e+00  -8.97150224e+00   7.24873939e+00
#    8.83517493e+00   2.52365187e+02   5.13639857e+00   2.95493825e-01
#   -1.52888885e-01  -3.44961142e-01]
# Cross-validated scores: [ 0.71237242 -4.23679543  0.86937816  0.72836386  0.69534899  0.78503744
#   0.75123209  0.7377062   0.7742133   0.65236043]
# Mean score =  0.246921746439
# (  clicks  on FB/ BuzzFeed Australia  ) Cross-Predicted Accuracy (R2):  0.177521757528
# WORKING ON FB PAGE:  LOLA
# Testing for shares!
# Coefficients:  [ 0.67845025  0.02821662  1.17491507  2.98074278 -0.43273245  4.67393352
#  -0.61982058  0.09571664 -0.00821225 -0.06682071]
# Cross-validated scores: [ 0.66710735  0.89843486 -0.79203138  0.83430047  0.74814671  0.60734756
#   0.84614159 -0.13029389 -0.87217698  0.24537905]
# Mean score =  0.305235533075
# (  share  on FB/ LOLA  ) Cross-Predicted Accuracy (R2):  0.446738280687
# Testing for clicks!
# Coefficients:  [ 12.94194993   3.48644397  27.05730731  11.72854282 -21.74984739
#   -3.46655518  -0.59249861   3.09455958   0.6538084   -3.34425741]
# Cross-validated scores: [ 0.92164711  0.61615823  0.78321771  0.55388302  0.59427366  0.20339447
#   0.97326727  0.50190268  0.5089085   0.28241975]
# Mean score =  0.593907240886
# (  clicks  on FB/ LOLA  ) Cross-Predicted Accuracy (R2):  0.559805167602
# WORKING ON FB PAGE:  BuzzFeed Style
# Testing for shares!
# Coefficients:  [-0.15442712 -0.16449966  0.29114203  0.78646881 -0.2487448   8.8907258
#   0.18931262  0.00908265 -0.03572954  0.02818232]
# Cross-validated scores: [ 0.79175911  0.5315465   0.79296587  0.74456173  0.85908655  0.73861572
#   0.89568639  0.83840833  0.84387216  0.9211084 ]
# Mean score =  0.795761075911
# (  share  on FB/ BuzzFeed Style  ) Cross-Predicted Accuracy (R2):  0.806352652909
# Testing for clicks!
# Coefficients:  [  0.87661857  -6.39185773  -0.49575164  10.47165527  -5.80334944
#   59.14403852   9.8314751    0.7877287   -0.77358843   0.07388582]
# Cross-validated scores: [ 0.80820122  0.81724302  0.8738837   0.65261655  0.8048923   0.86044148
#   0.87534732  0.88969388  0.8766537   0.87842275]
# Mean score =  0.83373959188
# (  clicks  on FB/ BuzzFeed Style  ) Cross-Predicted Accuracy (R2):  0.8437187266
# WORKING ON FB PAGE:  Top Knot
# NEED MORE DATA - SKIPPING PAGE!

# %%
###Regression - see what the coefficients are for each page: 
from pandas.stats.api import ols

pages = ['BuzzFeed Books', 'Tasty', 'BuzzFeed España', 'BuzzFeed Scotland', 'SOML', 'BuzzFeed News BR', 'Proper Tasty', 'BuzzFeed News','Obsessed by BuzzFeed', 'BuzzFeed France', 'BuzzFeed', 'BuzzFeed World', 'BuzzFeed Australia', 'LOLA','BuzzFeed Style','Top Knot',]
# page_info = pd.read_csv('datapoints/data-points-Tasty.csv')

for page in pages:
    print("WORKING ON FB PAGE: ",page)
    train = pd.read_csv(filepath+'datapoints/data-points-'+ page + '.csv')

    print('Clicks performance')
    features = ['consumptions_by_type__link_clicks',
                'consumptions_by_type__other_clicks', 
                'reactions_like_total',
                'stories_by_action_type__comment', 
                'stories_by_action_type__like',
                'stories_by_action_type__share', 
                'engaged_fan', 'fan_reach',
                'impressions', 
                'impressions_fan']

    res = ols(y = train['24_hours_clicks'], x = train[features])
    print(res)

    print('Share performance')
    features = ['consumptions_by_type__link_clicks',
                'consumptions_by_type__other_clicks', 
                'reactions_like_total',
                'stories_by_action_type__comment', 
                'stories_by_action_type__like',
                'stories_by_action_type__share', 
                'engaged_fan', 'fan_reach',
                'impressions', 
                'impressions_fan']

    res = ols(y = train['24_hours_share'], x = train[features])
    print(res)
# Out:
# WORKING ON FB PAGE:  BuzzFeed Books
# Clicks performance
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         976
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8749
# Adj R-squared:     0.8736
#
# Rmse:           3756.7969
#
# F-stat (10, 965):   674.6998, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 965
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    15.1989     1.0460      14.53     0.0000    13.1488    17.2491
# consumptions_by_type__other_clicks     2.8906     1.0594       2.73     0.0065     0.8142     4.9670
# reactions_like_total   -31.7646     5.8995      -5.38     0.0000   -43.3276   -20.2016
# stories_by_action_type__comment    -4.2262     4.9077      -0.86     0.3894   -13.8452     5.3929
# stories_by_action_type__like    32.5421     4.5705       7.12     0.0000    23.5840    41.5003
# --------------------------------------------------------------------------------
# stories_by_action_type__share    35.5260     6.2175       5.71     0.0000    23.3397    47.7122
#    engaged_fan    -5.4686     1.2181      -4.49     0.0000    -7.8560    -3.0811
#      fan_reach     0.7817     0.1278       6.12     0.0000     0.5312     1.0322
#    impressions    -0.3964     0.1281      -3.09     0.0020    -0.6474    -0.1453
# impressions_fan    -0.3438     0.1721      -2.00     0.0460    -0.6810    -0.0065
# --------------------------------------------------------------------------------
#      intercept  1613.2526   344.4675       4.68     0.0000   938.0963  2288.4090
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         976
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8098
# Adj R-squared:     0.8078
#
# Rmse:            194.0925
#
# F-stat (10, 965):   410.8556, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 965
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.1038     0.0540       1.92     0.0551    -0.0022     0.2097
# consumptions_by_type__other_clicks     0.0417     0.0547       0.76     0.4464    -0.0656     0.1490
# reactions_like_total    -0.5750     0.3048      -1.89     0.0595    -1.1723     0.0224
# stories_by_action_type__comment     1.0891     0.2536       4.30     0.0000     0.5922     1.5861
# stories_by_action_type__like     0.5083     0.2361       2.15     0.0316     0.0455     0.9711
# --------------------------------------------------------------------------------
# stories_by_action_type__share     9.6521     0.3212      30.05     0.0000     9.0225    10.2817
#    engaged_fan    -0.0875     0.0629      -1.39     0.1648    -0.2108     0.0359
#      fan_reach     0.0477     0.0066       7.23     0.0000     0.0348     0.0607
#    impressions    -0.0389     0.0066      -5.88     0.0000    -0.0519    -0.0260
# impressions_fan     0.0005     0.0089       0.06     0.9541    -0.0169     0.0179
# --------------------------------------------------------------------------------
#      intercept    -8.1287    17.7967      -0.46     0.6480   -43.0102    26.7528
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  Tasty
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         419
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8313
# Adj R-squared:     0.8271
#
# Rmse:          98121.5233
#
# F-stat (10, 408):   201.0260, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 408
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     9.6309     1.6629       5.79     0.0000     6.3716    12.8901
# consumptions_by_type__other_clicks     0.6171     1.8255       0.34     0.7355    -2.9610     4.1951
# reactions_like_total   -32.5384    28.6625      -1.14     0.2569   -88.7169    23.6401
# stories_by_action_type__comment   -38.8638    16.3092      -2.38     0.0176   -70.8298    -6.8978
# stories_by_action_type__like    75.3764    22.8332       3.30     0.0010    30.6234   120.1294
# --------------------------------------------------------------------------------
# stories_by_action_type__share     0.7494    19.2862       0.04     0.9690   -37.0515    38.5504
#    engaged_fan    -1.8335     1.9079      -0.96     0.3371    -5.5730     1.9060
#      fan_reach     0.2468     0.0739       3.34     0.0009     0.1019     0.3917
#    impressions     0.1403     0.0570       2.46     0.0142     0.0286     0.2520
# impressions_fan    -0.4042     0.0730      -5.54     0.0000    -0.5472    -0.2612
# --------------------------------------------------------------------------------
#      intercept 86675.4598 18144.5328       4.78     0.0000 51112.1754 122238.7442
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         419
# Number of Degrees of Freedom:   11
#
# R-squared:         0.9321
# Adj R-squared:     0.9305
#
# Rmse:           1185.7658
#
# F-stat (10, 408):   560.3913, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 408
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.0207     0.0201       1.03     0.3042    -0.0187     0.0601
# consumptions_by_type__other_clicks     0.0234     0.0221       1.06     0.2901    -0.0199     0.0666
# reactions_like_total     1.3104     0.3464       3.78     0.0002     0.6315     1.9893
# stories_by_action_type__comment    -1.0088     0.1971      -5.12     0.0000    -1.3951    -0.6225
# stories_by_action_type__like    -0.8785     0.2759      -3.18     0.0016    -1.4193    -0.3376
# --------------------------------------------------------------------------------
# stories_by_action_type__share     8.3085     0.2331      35.65     0.0000     7.8517     8.7653
#    engaged_fan    -0.0094     0.0231      -0.41     0.6823    -0.0546     0.0357
#      fan_reach     0.0012     0.0009       1.33     0.1838    -0.0006     0.0029
#    impressions     0.0009     0.0007       1.28     0.2025    -0.0005     0.0022
# impressions_fan    -0.0023     0.0009      -2.56     0.0109    -0.0040    -0.0005
# --------------------------------------------------------------------------------
#      intercept   115.4819   219.2706       0.53     0.5987  -314.2886   545.2523
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed España
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         703
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7626
# Adj R-squared:     0.7592
#
# Rmse:           1294.3360
#
# F-stat (10, 692):   222.2843, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 692
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    44.7336     3.5158      12.72     0.0000    37.8426    51.6246
# consumptions_by_type__other_clicks    11.4084     3.4305       3.33     0.0009     4.6846    18.1322
# reactions_like_total    30.5421    16.0813       1.90     0.0580    -0.9773    62.0615
# stories_by_action_type__comment    33.1879    13.8621       2.39     0.0169     6.0182    60.3576
# stories_by_action_type__like    32.5259    12.1486       2.68     0.0076     8.7146    56.3372
# --------------------------------------------------------------------------------
# stories_by_action_type__share    32.7004    14.4952       2.26     0.0244     4.2898    61.1110
#    engaged_fan   -36.5539     3.8747      -9.43     0.0000   -44.1484   -28.9595
#      fan_reach     1.8827     0.3345       5.63     0.0000     1.2270     2.5383
#    impressions    -1.0113     0.2878      -3.51     0.0005    -1.5753    -0.4473
# impressions_fan    -0.7838     0.3388      -2.31     0.0210    -1.4478    -0.1197
# --------------------------------------------------------------------------------
#      intercept   269.9335    87.9154       3.07     0.0022    97.6193   442.2477
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         703
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7242
# Adj R-squared:     0.7203
#
# Rmse:             76.9923
#
# F-stat (10, 692):   181.7510, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 692
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     1.8174     0.2091       8.69     0.0000     1.4075     2.2273
# consumptions_by_type__other_clicks     1.0088     0.2041       4.94     0.0000     0.6089     1.4088
# reactions_like_total     1.3687     0.9566       1.43     0.1529    -0.5062     3.2436
# stories_by_action_type__comment     0.4259     0.8246       0.52     0.6057    -1.1903     2.0420
# stories_by_action_type__like     1.7498     0.7226       2.42     0.0157     0.3334     3.1662
# --------------------------------------------------------------------------------
# stories_by_action_type__share     9.9387     0.8622      11.53     0.0000     8.2487    11.6287
#    engaged_fan    -1.8351     0.2305      -7.96     0.0000    -2.2868    -1.3833
#      fan_reach     0.0543     0.0199       2.73     0.0065     0.0153     0.0933
#    impressions    -0.0054     0.0171      -0.31     0.7540    -0.0389     0.0282
# impressions_fan    -0.0571     0.0202      -2.83     0.0048    -0.0966    -0.0176
# --------------------------------------------------------------------------------
#      intercept    15.0011     5.2296       2.87     0.0042     4.7512    25.2511
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed Scotland
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         166
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8902
# Adj R-squared:     0.8831
#
# Rmse:           2494.9844
#
# F-stat (10, 155):   125.6319, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 155
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    14.8701     3.2971       4.51     0.0000     8.4078    21.3325
# consumptions_by_type__other_clicks    -0.4511     3.3008      -0.14     0.8915    -6.9206     6.0185
# reactions_like_total  -102.2506    32.4168      -3.15     0.0019  -165.7876   -38.7136
# stories_by_action_type__comment   -10.7741     8.3123      -1.30     0.1968   -27.0663     5.5181
# stories_by_action_type__like    94.0350    27.3286       3.44     0.0007    40.4710   147.5989
# --------------------------------------------------------------------------------
# stories_by_action_type__share   213.7385    45.8227       4.66     0.0000   123.9260   303.5511
#    engaged_fan    -6.2904     4.1009      -1.53     0.1271   -14.3281     1.7474
#      fan_reach     2.7243     0.6543       4.16     0.0001     1.4419     4.0067
#    impressions     0.0066     0.3766       0.02     0.9859    -0.7315     0.7448
# impressions_fan    -2.6991     0.7054      -3.83     0.0002    -4.0818    -1.3165
# --------------------------------------------------------------------------------
#      intercept  2524.9277   652.2559       3.87     0.0002  1246.5062  3803.3493
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         166
# Number of Degrees of Freedom:   11
#
# R-squared:         0.5925
# Adj R-squared:     0.5663
#
# Rmse:            124.5561
#
# F-stat (10, 155):    22.5412, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 155
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.1807     0.1646      -1.10     0.2741    -0.5033     0.1420
# consumptions_by_type__other_clicks    -0.4257     0.1648      -2.58     0.0107    -0.7487    -0.1028
# reactions_like_total    -2.9072     1.6183      -1.80     0.0744    -6.0792     0.2647
# stories_by_action_type__comment     0.3186     0.4150       0.77     0.4438    -0.4947     1.1320
# stories_by_action_type__like     2.3509     1.3643       1.72     0.0869    -0.3232     5.0249
# --------------------------------------------------------------------------------
# stories_by_action_type__share    15.1232     2.2876       6.61     0.0000    10.6395    19.6069
#    engaged_fan     0.2642     0.2047       1.29     0.1987    -0.1370     0.6655
#      fan_reach     0.0000     0.0327       0.00     0.9999    -0.0640     0.0640
#    impressions    -0.0180     0.0188      -0.96     0.3389    -0.0549     0.0188
# impressions_fan     0.0159     0.0352       0.45     0.6516    -0.0531     0.0850
# --------------------------------------------------------------------------------
#      intercept    -1.8528    32.5623      -0.06     0.9547   -65.6750    61.9693
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  SOML
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         130
# Number of Degrees of Freedom:   11
#
# R-squared:         0.9426
# Adj R-squared:     0.9378
#
# Rmse:          11492.0294
#
# F-stat (10, 119):   195.5784, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 119
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     6.1814     4.3987       1.41     0.1625    -2.4401    14.8029
# consumptions_by_type__other_clicks    -7.8757     3.7393      -2.11     0.0373   -15.2047    -0.5466
# reactions_like_total   -18.7781    21.3484      -0.88     0.3808   -60.6211    23.0648
# stories_by_action_type__comment    55.7158    27.2223       2.05     0.0429     2.3600   109.0716
# stories_by_action_type__like    22.0579    16.9174       1.30     0.1948   -11.1003    55.2161
# --------------------------------------------------------------------------------
# stories_by_action_type__share    35.4453    30.8173       1.15     0.2524   -24.9566    95.8472
#    engaged_fan     5.4381     5.0327       1.08     0.2821    -4.4261    15.3023
#      fan_reach     0.3238     0.3978       0.81     0.4173    -0.4559     1.1036
#    impressions     0.2178     0.5656       0.38     0.7009    -0.8909     1.3264
# impressions_fan    -0.6459     0.6655      -0.97     0.3338    -1.9503     0.6586
# --------------------------------------------------------------------------------
#      intercept  7677.1148  3714.9705       2.07     0.0409   395.7726 14958.4570
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         130
# Number of Degrees of Freedom:   11
#
# R-squared:         0.9233
# Adj R-squared:     0.9169
#
# Rmse:            227.2272
#
# F-stat (10, 119):   143.2647, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 119
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.0823     0.0870       0.95     0.3461    -0.0882     0.2527
# consumptions_by_type__other_clicks     0.0259     0.0739       0.35     0.7267    -0.1190     0.1708
# reactions_like_total    -0.8103     0.4221      -1.92     0.0573    -1.6376     0.0170
# stories_by_action_type__comment    -0.4430     0.5383      -0.82     0.4122    -1.4980     0.6120
# stories_by_action_type__like     0.8494     0.3345       2.54     0.0124     0.1938     1.5050
# --------------------------------------------------------------------------------
# stories_by_action_type__share     8.6125     0.6093      14.13     0.0000     7.4182     9.8068
#    engaged_fan    -0.0650     0.0995      -0.65     0.5146    -0.2601     0.1300
#      fan_reach     0.0012     0.0079       0.15     0.8808    -0.0142     0.0166
#    impressions    -0.0048     0.0112      -0.43     0.6686    -0.0267     0.0171
# impressions_fan     0.0018     0.0132       0.14     0.8901    -0.0240     0.0276
# --------------------------------------------------------------------------------
#      intercept   119.3913    73.4546       1.63     0.1067   -24.5797   263.3622
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed News BR
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         435
# Number of Degrees of Freedom:   11
#
# R-squared:         0.6244
# Adj R-squared:     0.6155
#
# Rmse:          12909.9058
#
# F-stat (10, 424):    70.4828, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 424
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -8.1768     2.5305      -3.23     0.0013   -13.1367    -3.2170
# consumptions_by_type__other_clicks    -0.4238     1.7077      -0.25     0.8041    -3.7709     2.9234
# reactions_like_total   -78.0891    11.5892      -6.74     0.0000  -100.8039   -55.3743
# stories_by_action_type__comment  -297.9446    51.0892      -5.83     0.0000  -398.0793  -197.8098
# stories_by_action_type__like    46.3677    10.3711       4.47     0.0000    26.0405    66.6950
# --------------------------------------------------------------------------------
# stories_by_action_type__share   212.5716    57.6023       3.69     0.0003    99.6711   325.4721
#    engaged_fan   126.3578     8.8128      14.34     0.0000   109.0848   143.6309
#      fan_reach    26.3922     4.3424       6.08     0.0000    17.8812    34.9032
#    impressions     0.2778     0.1193       2.33     0.0204     0.0440     0.5117
# impressions_fan   -26.8337     3.4386      -7.80     0.0000   -33.5734   -20.0941
# --------------------------------------------------------------------------------
#      intercept  3707.7951  1176.2566       3.15     0.0017  1402.3322  6013.2580
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         435
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7457
# Adj R-squared:     0.7397
#
# Rmse:            750.6747
#
# F-stat (10, 424):   124.3222, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 424
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.9954     0.1471      -6.76     0.0000    -1.2838    -0.7070
# consumptions_by_type__other_clicks     0.2850     0.0993       2.87     0.0043     0.0904     0.4796
# reactions_like_total    -3.8852     0.6739      -5.77     0.0000    -5.2060    -2.5644
# stories_by_action_type__comment   -25.1200     2.9707      -8.46     0.0000   -30.9426   -19.2974
# stories_by_action_type__like     2.5360     0.6030       4.21     0.0000     1.3540     3.7180
# --------------------------------------------------------------------------------
# stories_by_action_type__share    21.2832     3.3494       6.35     0.0000    14.7183    27.8480
#    engaged_fan     6.3273     0.5124      12.35     0.0000     5.3230     7.3317
#      fan_reach     0.9411     0.2525       3.73     0.0002     0.4462     1.4360
#    impressions     0.0159     0.0069       2.29     0.0225     0.0023     0.0295
# impressions_fan    -1.0612     0.1999      -5.31     0.0000    -1.4531    -0.6693
# --------------------------------------------------------------------------------
#      intercept   202.3707    68.3960       2.96     0.0033    68.3145   336.4269
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  Proper Tasty
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         8
# Number of Degrees of Freedom:   8
#
# R-squared:         1.0000
# Adj R-squared:        nan
#
# Rmse:                 inf
#
# F-stat (10, 0):        nan, p-value:        nan
#
# Degrees of Freedom: model 7, resid 0
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    17.3964        nan        nan        nan        nan        nan
# consumptions_by_type__other_clicks   -46.9118        inf      -0.00        nan       -inf        inf
# reactions_like_total   119.9712        inf       0.00        nan       -inf        inf
# stories_by_action_type__comment   355.6035        inf       0.00        nan       -inf        inf
# stories_by_action_type__like    43.7639        inf       0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
# stories_by_action_type__share   163.0229        inf       0.00        nan       -inf        inf
#    engaged_fan    -3.5662        inf      -0.00        nan       -inf        inf
#      fan_reach    -1.7143        inf      -0.00        nan       -inf        inf
#    impressions    -0.8657        inf      -0.00        nan       -inf        inf
# impressions_fan     2.0895        nan        nan        nan        nan        nan
# --------------------------------------------------------------------------------
#      intercept    -0.0510        inf      -0.00        nan       -inf        inf
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         8
# Number of Degrees of Freedom:   8
#
# R-squared:         1.0000
# Adj R-squared:        nan
#
# Rmse:                 inf
#
# F-stat (10, 0):        nan, p-value:        nan
#
# Degrees of Freedom: model 7, resid 0
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.0226        nan        nan        nan        nan        nan
# consumptions_by_type__other_clicks    -3.2300        inf      -0.00        nan       -inf        inf
# reactions_like_total     4.8703        inf       0.00        nan       -inf        inf
# stories_by_action_type__comment    11.3778        inf       0.00        nan       -inf        inf
# stories_by_action_type__like     2.3857        inf       0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
# stories_by_action_type__share     6.2706        inf       0.00        nan       -inf        inf
#    engaged_fan     0.4833        inf       0.00        nan       -inf        inf
#      fan_reach    -0.0213        inf      -0.00        nan       -inf        inf
#    impressions     0.2691        inf       0.00        nan       -inf        inf
# impressions_fan    -0.2622        nan        nan        nan        nan        nan
# --------------------------------------------------------------------------------
#      intercept    -0.0015        inf      -0.00        nan       -inf        inf
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed News
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         2619
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8107
# Adj R-squared:     0.8100
#
# Rmse:           6671.8929
#
# F-stat (10, 2608):  1117.1844, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 2608
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     6.7058     0.7387       9.08     0.0000     5.2579     8.1537
# consumptions_by_type__other_clicks    -3.6778     0.5920      -6.21     0.0000    -4.8380    -2.5175
# reactions_like_total    -1.9379     1.5142      -1.28     0.2007    -4.9058     1.0300
# stories_by_action_type__comment    16.8896     4.3054       3.92     0.0001     8.4511    25.3281
# stories_by_action_type__like     6.1225     1.5296       4.00     0.0001     3.1245     9.1205
# --------------------------------------------------------------------------------
# stories_by_action_type__share    29.0070     3.7130       7.81     0.0000    21.7296    36.2844
#    engaged_fan     3.9434     0.9470       4.16     0.0000     2.0872     5.7996
#      fan_reach     0.2008     0.0507       3.96     0.0001     0.1015     0.3002
#    impressions    -0.7736     0.0646     -11.98     0.0000    -0.9001    -0.6471
# impressions_fan     0.5345     0.0763       7.01     0.0000     0.3851     0.6840
# --------------------------------------------------------------------------------
#      intercept  2087.7688   288.7695       7.23     0.0000  1521.7806  2653.7570
# ---------------------------------End of Summary---------------------------------
#
# Share performance
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1187: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1187: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1195: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/pandas/stats/ols.py:336: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self._var_beta_raw))
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1814: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         2619
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7632
# Adj R-squared:     0.7623
#
# Rmse:            285.6706
#
# F-stat (10, 2608):   840.6060, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 2608
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.0819     0.0316      -2.59     0.0097    -0.1439    -0.0199
# consumptions_by_type__other_clicks    -0.1824     0.0253      -7.20     0.0000    -0.2321    -0.1328
# reactions_like_total     0.0117     0.0648       0.18     0.8572    -0.1154     0.1387
# stories_by_action_type__comment     2.2029     0.1843      11.95     0.0000     1.8416     2.5642
# stories_by_action_type__like     0.0836     0.0655       1.28     0.2019    -0.0448     0.2120
# --------------------------------------------------------------------------------
# stories_by_action_type__share     7.0033     0.1590      44.05     0.0000     6.6917     7.3149
#    engaged_fan     0.1427     0.0405       3.52     0.0004     0.0632     0.2221
#      fan_reach     0.0083     0.0022       3.82     0.0001     0.0040     0.0126
#    impressions    -0.0205     0.0028      -7.43     0.0000    -0.0259    -0.0151
# impressions_fan     0.0122     0.0033       3.74     0.0002     0.0058     0.0186
# --------------------------------------------------------------------------------
#      intercept    26.0224    12.3643       2.10     0.0354     1.7884    50.2563
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  Obsessed by BuzzFeed
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         1196
# Number of Degrees of Freedom:   11
#
# R-squared:         0.6345
# Adj R-squared:     0.6314
#
# Rmse:           2272.0357
#
# F-stat (10, 1185):   205.6950, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 1185
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     2.6085     0.6294       4.14     0.0000     1.3749     3.8421
# consumptions_by_type__other_clicks    -2.5876     0.8297      -3.12     0.0019    -4.2138    -0.9614
# reactions_like_total   -39.3433     8.1373      -4.83     0.0000   -55.2923   -23.3942
# stories_by_action_type__comment     9.7036     7.2006       1.35     0.1780    -4.4096    23.8168
# stories_by_action_type__like    27.9399     6.2092       4.50     0.0000    15.7699    40.1098
# --------------------------------------------------------------------------------
# stories_by_action_type__share    18.1010     8.1417       2.22     0.0264     2.1432    34.0588
#    engaged_fan     5.3461     0.8974       5.96     0.0000     3.5871     7.1050
#      fan_reach     0.1628     0.0679       2.40     0.0167     0.0297     0.2958
#    impressions     0.0064     0.0412       0.16     0.8763    -0.0744     0.0872
# impressions_fan    -0.2261     0.0595      -3.80     0.0002    -0.3427    -0.1096
# --------------------------------------------------------------------------------
#      intercept   411.9692   110.6903       3.72     0.0002   195.0163   628.9221
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         1196
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7981
# Adj R-squared:     0.7964
#
# Rmse:             63.5669
#
# F-stat (10, 1185):   468.3048, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 1185
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.0069     0.0176       0.39     0.6959    -0.0276     0.0414
# consumptions_by_type__other_clicks    -0.0371     0.0232      -1.60     0.1106    -0.0826     0.0084
# reactions_like_total     0.9176     0.2277       4.03     0.0001     0.4714     1.3638
# stories_by_action_type__comment     0.5940     0.2015       2.95     0.0033     0.1992     0.9889
# stories_by_action_type__like    -0.1206     0.1737      -0.69     0.4877    -0.4611     0.2199
# --------------------------------------------------------------------------------
# stories_by_action_type__share     4.3007     0.2278      18.88     0.0000     3.8542     4.7471
#    engaged_fan     0.0225     0.0251       0.90     0.3701    -0.0267     0.0717
#      fan_reach    -0.0007     0.0019      -0.39     0.6952    -0.0045     0.0030
#    impressions    -0.0057     0.0012      -4.93     0.0000    -0.0079    -0.0034
# impressions_fan     0.0007     0.0017       0.40     0.6873    -0.0026     0.0039
# --------------------------------------------------------------------------------
#      intercept    11.0221     3.0969       3.56     0.0004     4.9522    17.0920
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed France
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         848
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8744
# Adj R-squared:     0.8729
#
# Rmse:           5389.9325
#
# F-stat (10, 837):   582.6730, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 837
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    12.2767     2.2811       5.38     0.0000     7.8058    16.7476
# consumptions_by_type__other_clicks   -12.1229     2.9354      -4.13     0.0000   -17.8763    -6.3695
# reactions_like_total   225.7765    19.6094      11.51     0.0000   187.3420   264.2110
# stories_by_action_type__comment   138.4619    17.5390       7.89     0.0000   104.0856   172.8383
# stories_by_action_type__like  -144.3993    15.5953      -9.26     0.0000  -174.9660  -113.8326
# --------------------------------------------------------------------------------
# stories_by_action_type__share   241.7037    28.8896       8.37     0.0000   185.0800   298.3273
#    engaged_fan     4.5280     2.7585       1.64     0.1011    -0.8786     9.9346
#      fan_reach     1.4207     0.3636       3.91     0.0001     0.7080     2.1334
#    impressions    -0.3374     0.0993      -3.40     0.0007    -0.5319    -0.1428
# impressions_fan    -1.3663     0.2883      -4.74     0.0000    -1.9314    -0.8013
# --------------------------------------------------------------------------------
#      intercept  2914.3588   356.2585       8.18     0.0000  2216.0922  3612.6253
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         848
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7777
# Adj R-squared:     0.7751
#
# Rmse:            129.9064
#
# F-stat (10, 837):   292.8841, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 837
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.0478     0.0550      -0.87     0.3845    -0.1556     0.0599
# consumptions_by_type__other_clicks    -0.2505     0.0707      -3.54     0.0004    -0.3892    -0.1119
# reactions_like_total    -0.7557     0.4726      -1.60     0.1102    -1.6821     0.1706
# stories_by_action_type__comment     1.6725     0.4227       3.96     0.0001     0.8440     2.5010
# stories_by_action_type__like     0.4512     0.3759       1.20     0.2303    -0.2855     1.1879
# --------------------------------------------------------------------------------
# stories_by_action_type__share    16.2088     0.6963      23.28     0.0000    14.8441    17.5736
#    engaged_fan     0.1077     0.0665       1.62     0.1057    -0.0226     0.2380
#      fan_reach     0.0257     0.0088       2.94     0.0034     0.0086     0.0429
#    impressions    -0.0064     0.0024      -2.66     0.0079    -0.0111    -0.0017
# impressions_fan    -0.0170     0.0069      -2.44     0.0148    -0.0306    -0.0033
# --------------------------------------------------------------------------------
#      intercept    17.1892     8.5864       2.00     0.0456     0.3598    34.0186
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         4885
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8497
# Adj R-squared:     0.8493
#
# Rmse:          46863.7556
#
# F-stat (10, 4874):  2754.4745, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 4874
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     7.5453     0.4257      17.73     0.0000     6.7109     8.3796
# consumptions_by_type__other_clicks    -0.7835     0.3746      -2.09     0.0365    -1.5178    -0.0492
# reactions_like_total    11.9927     2.2812       5.26     0.0000     7.5216    16.4638
# stories_by_action_type__comment     7.8124     3.4656       2.25     0.0242     1.0199    14.6050
# stories_by_action_type__like    -1.0647     2.0211      -0.53     0.5983    -5.0260     2.8965
# --------------------------------------------------------------------------------
# stories_by_action_type__share    76.0101     4.8436      15.69     0.0000    66.5166    85.5036
#    engaged_fan     0.6542     0.5176       1.26     0.2063    -0.3602     1.6686
#      fan_reach     0.9195     0.0651      14.12     0.0000     0.7918     1.0472
#    impressions    -0.8766     0.0521     -16.81     0.0000    -0.9788    -0.7744
# impressions_fan     0.0327     0.0714       0.46     0.6471    -0.1072     0.1726
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# stories_by_action_type__share   252.0519    11.6939      21.55     0.0000   229.1319   274.9719
#    engaged_fan     6.0745     0.6412       9.47     0.0000     4.8177     7.3313
#      fan_reach     0.2441     0.0841       2.90     0.0037     0.0793     0.4089
#    impressions    -0.1361     0.0139      -9.79     0.0000    -0.1634    -0.1089
# impressions_fan    -0.3154     0.0758      -4.16     0.0000    -0.4640    -0.1667
# --------------------------------------------------------------------------------
#      intercept  5575.6093   300.8632      18.53     0.0000  4985.9174  6165.3012
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         3056
# Number of Degrees of Freedom:   11
#
# R-squared:         0.7246
# Adj R-squared:     0.7236
#
# Rmse:            119.4848
#
# F-stat (10, 3045):   800.9638, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 3045
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.0590     0.0078       7.56     0.0000     0.0437     0.0743
# consumptions_by_type__other_clicks     0.0085     0.0103       0.82     0.4094    -0.0117     0.0287
# reactions_like_total     0.0342     0.1249       0.27     0.7840    -0.2105     0.2790
# stories_by_action_type__comment    -0.0752     0.0357      -2.11     0.0350    -0.1451    -0.0053
# stories_by_action_type__like     0.0758     0.1103       0.69     0.4923    -0.1404     0.2919
# --------------------------------------------------------------------------------
# stories_by_action_type__share    10.9997     0.1869      58.86     0.0000    10.6335    11.3660
#    engaged_fan    -0.0438     0.0102      -4.28     0.0000    -0.0639    -0.0237
#      fan_reach     0.0038     0.0013       2.81     0.0050     0.0011     0.0064
#    impressions    -0.0055     0.0002     -24.64     0.0000    -0.0059    -0.0050
# impressions_fan     0.0010     0.0012       0.80     0.4210    -0.0014     0.0034
# --------------------------------------------------------------------------------
#      intercept    14.0954     4.8077       2.93     0.0034     4.6723    23.5185
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  LOLA
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         120
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8600
# Adj R-squared:     0.8471
#
# Rmse:           1095.4521
#
# F-stat (10, 109):    66.9495, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 109
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    15.8827     4.9858       3.19     0.0019     6.1104    25.6549
# consumptions_by_type__other_clicks     5.3035     4.4385       1.19     0.2347    -3.3959    14.0030
# reactions_like_total    27.2703    11.3977       2.39     0.0184     4.9308    49.6099
# stories_by_action_type__comment    16.7205    43.6716       0.38     0.7026   -68.8760   102.3169
# stories_by_action_type__like   -18.6602     8.3463      -2.24     0.0274   -35.0189    -2.3014
# --------------------------------------------------------------------------------
# stories_by_action_type__share    -2.0157    12.9823      -0.16     0.8769   -27.4610    23.4296
#    engaged_fan    -4.5521     6.1488      -0.74     0.4607   -16.6037     7.4995
#      fan_reach     3.2573     0.5337       6.10     0.0000     2.2113     4.3033
#    impressions     0.5425     0.2892       1.88     0.0634    -0.0244     1.1095
# impressions_fan    -3.3368     0.5747      -5.81     0.0000    -4.4634    -2.2103
# --------------------------------------------------------------------------------
#      intercept    82.8850   152.4657       0.54     0.5878  -215.9477   381.7176
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         120
# Number of Degrees of Freedom:   11
#
# R-squared:         0.9147
# Adj R-squared:     0.9069
#
# Rmse:             39.4906
#
# F-stat (10, 109):   116.9409, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 109
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     0.4172     0.1797       2.32     0.0222     0.0649     0.7694
# consumptions_by_type__other_clicks     0.3753     0.1600       2.35     0.0208     0.0617     0.6889
# reactions_like_total     1.3267     0.4109       3.23     0.0016     0.5213     2.1320
# stories_by_action_type__comment     1.2804     1.5743       0.81     0.4178    -1.8053     4.3661
# stories_by_action_type__like    -0.9391     0.3009      -3.12     0.0023    -1.5288    -0.3493
# --------------------------------------------------------------------------------
# stories_by_action_type__share     4.8506     0.4680      10.36     0.0000     3.9333     5.7679
#    engaged_fan    -0.3826     0.2217      -1.73     0.0872    -0.8170     0.0519
#      fan_reach     0.1232     0.0192       6.40     0.0000     0.0854     0.1609
#    impressions     0.0174     0.0104       1.67     0.0981    -0.0030     0.0378
# impressions_fan    -0.1162     0.0207      -5.61     0.0000    -0.1568    -0.0756
# --------------------------------------------------------------------------------
#      intercept    -1.0840     5.4963      -0.20     0.8440   -11.8568     9.6888
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  BuzzFeed Style
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         1494
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8730
# Adj R-squared:     0.8721
#
# Rmse:           7298.2975
#
# F-stat (10, 1483):  1019.0236, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 1483
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     1.5386     1.0527       1.46     0.1441    -0.5247     3.6019
# consumptions_by_type__other_clicks    -6.0993     0.9408      -6.48     0.0000    -7.9432    -4.2554
# reactions_like_total    -5.7857     9.3799      -0.62     0.5374   -24.1703    12.5989
# stories_by_action_type__comment     5.8545     7.7069       0.76     0.4476    -9.2510    20.9600
# stories_by_action_type__like    -1.2170     7.7834      -0.16     0.8758   -16.4725    14.0385
# --------------------------------------------------------------------------------
# stories_by_action_type__share    61.4675     7.9946       7.69     0.0000    45.7981    77.1370
#    engaged_fan     8.8512     1.2196       7.26     0.0000     6.4607    11.2417
#      fan_reach     0.8167     0.0922       8.86     0.0000     0.6359     0.9974
#    impressions    -0.7880     0.1022      -7.71     0.0000    -0.9883    -0.5878
# impressions_fan     0.0860     0.1315       0.65     0.5133    -0.1718     0.3437
# --------------------------------------------------------------------------------
#      intercept  1787.7184   420.4901       4.25     0.0000   963.5578  2611.8789
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         1494
# Number of Degrees of Freedom:   11
#
# R-squared:         0.8703
# Adj R-squared:     0.8694
#
# Rmse:            161.3680
#
# F-stat (10, 1483):   994.8838, p-value:     0.0000
#
# Degrees of Freedom: model 10, resid 1483
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.0907     0.0233      -3.90     0.0001    -0.1363    -0.0450
# consumptions_by_type__other_clicks    -0.0948     0.0208      -4.56     0.0000    -0.1355    -0.0540
# reactions_like_total     0.8827     0.2074       4.26     0.0000     0.4763     1.2892
# stories_by_action_type__comment     0.2645     0.1704       1.55     0.1209    -0.0695     0.5984
# stories_by_action_type__like    -0.6438     0.1721      -3.74     0.0002    -0.9811    -0.3065
# --------------------------------------------------------------------------------
# stories_by_action_type__share     8.3112     0.1768      47.02     0.0000     7.9648     8.6577
#    engaged_fan     0.1125     0.0270       4.17     0.0000     0.0597     0.1654
#      fan_reach     0.0115     0.0020       5.66     0.0000     0.0076     0.0155
#    impressions    -0.0320     0.0023     -14.15     0.0000    -0.0364    -0.0275
# impressions_fan     0.0228     0.0029       7.82     0.0000     0.0171     0.0284
# --------------------------------------------------------------------------------
#      intercept   -11.2983     9.2972      -1.22     0.2245   -29.5208     6.9242
# ---------------------------------End of Summary---------------------------------
#
# WORKING ON FB PAGE:  Top Knot
# Clicks performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         4
# Number of Degrees of Freedom:   4
#
# R-squared:         1.0000
# Adj R-squared:        nan
#
# Rmse:                 inf
#
# F-stat (10, 0):        nan, p-value:        nan
#
# Degrees of Freedom: model 3, resid 0
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks     3.6220        nan        nan        nan        nan        nan
# consumptions_by_type__other_clicks     0.2567        inf       0.00        nan       -inf        inf
# reactions_like_total    -0.4086        nan        nan        nan        nan        nan
# stories_by_action_type__comment     0.0514        nan        nan        nan        nan        nan
# stories_by_action_type__like    -0.5742        inf      -0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
# stories_by_action_type__share    -0.0446        nan        nan        nan        nan        nan
#    engaged_fan     2.8332        inf       0.00        nan       -inf        inf
#      fan_reach    -4.6491        nan        nan        nan        nan        nan
#    impressions     3.1694        nan        nan        nan        nan        nan
# impressions_fan     0.6396        nan        nan        nan        nan        nan
# --------------------------------------------------------------------------------
#      intercept    -0.0000        inf      -0.00        nan       -inf        inf
# ---------------------------------End of Summary---------------------------------
#
# Share performance
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <consumptions_by_type__link_clicks>
#              + <consumptions_by_type__other_clicks> + <reactions_like_total> + <stories_by_action_type__comment>
#              + <stories_by_action_type__like> + <stories_by_action_type__share>
#              + <engaged_fan> + <fan_reach> + <impressions> + <impressions_fan>
#              + <intercept>
#
# Number of Observations:         4
# Number of Degrees of Freedom:   4
#
# R-squared:         1.0000
# Adj R-squared:        nan
#
# Rmse:                 inf
#
# F-stat (10, 0):        nan, p-value:        nan
#
# Degrees of Freedom: model 3, resid 0
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# consumptions_by_type__link_clicks    -0.0032        nan        nan        nan        nan        nan
# consumptions_by_type__other_clicks     0.0006        inf       0.00        nan       -inf        inf
# reactions_like_total     0.0015        nan        nan        nan        nan        nan
# stories_by_action_type__comment    -0.0003        nan        nan        nan        nan        nan
# stories_by_action_type__like     0.0022        inf       0.00        nan       -inf        inf
# --------------------------------------------------------------------------------
# stories_by_action_type__share     0.0002        nan        nan        nan        nan        nan
#    engaged_fan     0.0002        inf       0.00        nan       -inf        inf
#      fan_reach     0.0160        nan        nan        nan        nan        nan
#    impressions    -0.0161        nan        nan        nan        nan        nan
# impressions_fan     0.0040        nan        nan        nan        nan        nan
# --------------------------------------------------------------------------------
#      intercept     0.0000        inf       0.00        nan       -inf        inf
# ---------------------------------End of Summary---------------------------------

# %%
print(1)
# Out:
# 1

# %%
###fit the regression - individual models for each page...
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline

pages = ['BuzzFeed Books', 'Tasty', 'BuzzFeed España', 'BuzzFeed Scotland', 'SOML', 'BuzzFeed News BR', 'Proper Tasty',]
# page_info = pd.read_csv('datapoints/data-points-Tasty.csv')
page_info = pd.read_csv('datapoints/data-points-Tasty.csv')

###generate DFs for analysis - X and Y
df = page_info.drop(['24_hours_clicks', '24_hours_share', 'within_30_mins', 'within_24_hours', 'stats_ts','stats_date', 'external_id'], 1)
y_share = page_info['24_hours_share']
y_clicks = page_info['24_hours_clicks']

# %%
###TESTING FOR SHARE - SAMPLE
# create training and testing vars

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
predictions[0:10]


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)
plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)
# Out:
# Testing for shares!
# (335, 10) (335,)
# (84, 10) (84,)
# Trial run - Score: 0.862231200074
# Cross-validated scores: [ 0.8899552   0.91378831  0.95155401  0.88587699  0.82907928  0.8201127
#   0.94755223  0.97400754  0.85335569  0.77727153]
# Mean accuracy =  0.884255349013
# Cross-Predicted Accuracy (R2): 0.914539008975

# %%
###TESTING FOR CLICKS - SAMPLE
# create training and testing vars

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
predictions[0:10]


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())

# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)
plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)
# Out:
# Testing for clicks!
# (335, 10) (335,)
# (84, 10) (84,)
# Trial run - Score: 0.857007678355
# Cross-validated scores: [ 0.82749929  0.85323014  0.84030388  0.71519913  0.82544176  0.78195891
#   0.77699426  0.92399787  0.43682741  0.6999772 ]
# Mean accuracy =  0.768142984371
# Cross-Predicted Accuracy (R2): 0.793194322121

# %%
##### LOW, MEDIUM, HIGH classification - 

#####
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics
import math

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
all_pages = list(train.buzz_account_display_name.unique())

# subsample = 1
subsample = 0

if subsample == 1:
    train = train[:1000]

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

###convert to log-scale
for feat in features:
    train[feat] = np.log(train[feat]+1)

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

X = df


####low, med, high classes;
low = 100
high = 10000

def get_class(x):
    if x < low:
        return 0
    elif x < high:
        return 1
    else:
        return 2

train['clicks_bucket'] = train['ext_twodays_consumptions_by_type__link_clicks'].apply(get_class)
train['share_bucket'] = train['ext_twodays_stories_by_action_type__share'].apply(get_class)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

cv = 5
nb_alpha = 0.01
# classifier = 'svm'
classifier = 'nb'
# classifier = 'logit'
# classifier ='rf'
logit_c = 1e5

####classifier
# clf = LinearSVC(C=1)
if classifier == 'nb':
    clf = MultinomialNB(alpha = nb_alpha)
if classifier == 'logit':
    clf = linear_model.LogisticRegression(C=logit_c)
#   Try penalty='l2' and 'l1'
if classifier == 'rf':
    clf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
else:
    clf = svm.SVC(kernel='linear')
    ###try different kernels

# predicted = cross_val_predict(clf, X, y, cv=cv)
# scores = metrics.accuracy_score(y, predicted)
scores = cross_val_score(clf, X, y, cv = cv)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# print("Accuracy: ", scores)

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

####classifier
# clf = LinearSVC(C=1)
if classifier == 'nb':
    clf = MultinomialNB(alpha = nb_alpha)
if classifier == 'logit':
    clf = linear_model.LogisticRegression(C=logit_c)
#   Try penalty='l2' and 'l1'
if classifier == 'rf':
    clf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
else:
    clf = svm.SVC(kernel='linear')
    ###try different kernels

# predicted = cross_val_predict(clf, X, y, cv=cv)
# scores = metrics.accuracy_score(y, predicted)
scores = cross_val_score(clf, X, y, cv = cv)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# print("Accuracy: ", scores)
# Out:
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# WITH cross-promotion features
# Testing for shares!
# Accuracy: 0.93 (+/- 0.01)
# Testing for clicks!
# Accuracy: 0.91 (+/- 0.01)

# %%
clf
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
train
# Out:
#                         buzz_external_id  buzz_post_parent_external_id  \
# 0       560066014088988_1340201119408803                           0.0
# 1      1457722161221362_1843726645954243                           0.0
# 2       574931839201643_1806270176067797                           0.0
# 3      1412406255640941_1914279005453661                           0.0
# 4        176835429378874_385699328492482                           0.0
# 5       666255463425866_1558273434224060                           0.0
# 6       618786471475708_1519848364702843                           0.0
# 7          21898300328_10156148388685329                           0.0
# 8      1431595910448704_1892206761054281                           0.0
# 9      1318800798260799_2228337970640406                           0.0
# 10       176835429378874_385698981825850                           0.0
# 11      667406426724032_1048539731944031                           0.0
# 12       139652223037176_453868761615519                           0.0
# 13       271522769938260_318876608536209                           0.0
# 14       280467515620435_466142523719599                           0.0
# 15       160545781051273_301630380276145                           0.0
# 16       224750834524198_469698423362770                           0.0
# 17      665729536839218_1410950982317066                           0.0
# 18         21898300328_10156148686725329                           0.0
# 19     1412984988933193_2015905888641097                           0.0
# 20      560066014088988_1338328922929356                           0.0
# 21      257431141042836_1302288899890383                           0.0
# 22     1726425217643704_1987117221574501                           0.0
# 23      322109601268040_1160930524052606                           0.0
# 24     1457722161221362_1843478149312426                           0.0
# 25      294474594013113_1243759455751284                           0.0
# 26       176835429378874_385478201847928                           0.0
# 27     1015149158500812_1722942504388137                           0.0
# 28      491452930867938_1679459008733985                           0.0
# 29      262059950576033_1301202263328458                           0.0
# ...                                  ...                           ...
# 5                    link            4370977
# 6                    link            4544346
# 7                    link            4540551
# 8                    link            4524151
# 9                    link            4539500
# 10                   link            4544079
# 11                   link            4543940
# 12                   link            4544076
# 13                   link            4372681
# 14                   link            4544408
# 15                   link            4544566
# 16                   link            4543910
# 17                   link            4544572
# 18                   link            4543910
# 19                   link            4544410
# 20                   link            4542285
# 21                   link            4536095
# 22                   link            4543153
# 23                   link            4539654
# 24                   link            4542689
# 25                   link            4519812
# 26                   link            4541843
# 27                   link            4544400
# 28                   link            4544411
# 29                   link            4543891
# ...                   ...                ...
# 37201                link            4129239
# 37202                link            4458572
# 37203                link            4458307
# 37204                link            4458544
# 37205                link            4458289
# 37206                link            4453073
# 37207                link            4457672
# 37208                link            4458446
# 37209                link            4458440
# 37210                link            4456508
# 37211                link            4457711
# 37212                link            4456684
# 37213                link            4440373
# 37214                link            4458451
# 37215                link            4457581
# 37216                link            4456850
# 37217                link            4457063
# 37218                link            4456323
# 37219                link            4457917
# 37220                link            4458414
# 37221                link            4453991
# 37222                link            4458550
# 37223                link            4458656
# 37224                link            4458159
# 37225                link            4170101
# 37226                link            4458411
# 37227                link            4458414
# 37228                link            4457117
# 37229                link            4454229
# 37230                link            4458554
#
#                                        buzz_campaign_uri  \
# 0               rate-these-netflix-shows-you-drama-queen
# 1                                                 cf-sw1
# 2                          public-sex-is-interesting-idk
# 3         na-briga-biscoito-x-bolacha-portugal-e-bolacha
# 4                                        doarawantstowin
# 5                                          bum-bum-liebe
# 6                                   inspiring-jfk-quotes
# 7      heres-25-shows-from-your-childhood-that-should...
# 8                do-you-notice-when-someone-steals-a-fry
# 9                                          whats-up-tree
# 10                           letter-from-a-dad-to-ariana
# 11     teenager-at-center-of-portland-stabbing-attack...
# 12     the-turnbull-governments-plan-to-drug-test-peo...
# 13                                     vamos-a-ver-parce
# 14     your-day-is-about-to-get-worse-because-whaboom...
# 15     parte-dos-aliados-de-temer-teme-que-novo-minis...
# 16        all-the-best-deals-on-amazon-today-may-29-2017
# 17     heres-what-we-learned-from-theresa-may-and-jer...
# 18        all-the-best-deals-on-amazon-today-may-29-2017
# 19                     pope-francis-justin-trudeau-photo
# 20                                         more-wine-plz
# 21     we-got-transformed-into-disney-villains-and-ho...
# 22                  people-are-sharing-their-worst-dates
# 23     12-classic-movies-you-might-not-have-known-wer...
# 24                                                cf-mzc
# 25                                 7-random-facts-may-29
# 26                                      alcohol-bakemono
# 27                     quizzes-de-ceniza-alma-quebradiza
# 28                         cheese-is-love-cheese-is-life
# 29                                                 prost
# ...                                                  ...
# 37201                                    introvert-party
# 37202                                             6-days
# 37203                                           petty-af
# 37204                                        lmao-no-cry
# 37205                              anabel-alonso-twitter
# 37206                   ways-to-save-money-february-2017
# 37207  heres-what-retail-workers-have-to-say-about-ho...
# 37208                                      instagramweek
# 37209                                               29on
# 37210    do-you-actually-have-a-terrible-sense-of-humour
# 37211  people-are-really-loving-the-way-this-guys-sis...
# 37212               instant-party-doll-oder-vibra-finger
# 37213                                            duck-af
# 37229           89.0              1             1
# 37230           89.0              1             0
#
# [37231 rows x 115 columns]

# %%
###fit the regression on all data points!

import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
############ LOG SCALING - 
###PREDICTION TASK - with cross-promotion
###Cross-validation
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

###convert to log-scale
for feat in features:
    train[feat] = np.log(train[feat]+1)

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

y_clicks = np.log(train['ext_twodays_consumptions_by_type__link_clicks'] + 1)
y_share = np.log(train['ext_twodays_stories_by_action_type__share'] + 1)

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)

###CONVERT FROM LOG TO EXPONENTS - 
y = np.exp(y) - 1
predictions = np.exp(predictions) - 1


plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)

###CONVERT FROM LOG TO EXPONENTS - 
y = np.exp(y) - 1
predictions = np.exp(predictions) - 1
######


plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())
###get coefficients
import numpy as np
print(pd.concat([pd.DataFrame(df.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1))
# Out:
# WITH cross-promotion features
# Testing for shares!
# (29784, 98) (29784,)
# (7447, 98) (7447,)
# Predict  share
# Trial run - Score: 0.913108573506
# Cross-validated scores: [ 0.92059344  0.91951683  0.91061283  0.92046387  0.90276891  0.84674781
#   0.87447005  0.86826673  0.90148528  0.90815865]
# Mean accuracy =  0.897308439345
# Cross-Predicted Accuracy (R2): 0.455529315632
# Mean Absolute Error:  120.432294303
# Mean values:  287.1133732642153  | percent error:  0.419459020434
# Testing for clicks!
# (29784, 98) (29784,)
# (7447, 98) (7447,)
# Predict  clicks
# Trial run - Score: 0.923188744131
# Cross-validated scores: [ 0.94215752  0.94075829  0.90645149  0.93957797  0.87895369  0.82804802
#   0.84025257  0.85839203  0.93221855  0.92886683]
# Mean accuracy =  0.899567695025
# Cross-Predicted Accuracy (R2): 0.718131923118
# Mean Absolute Error:  8189.26699727
# Mean values:  26589.06833015498  | percent error:  0.307993755012
#                                                 0         0
# 0    ext_table1_consumptions_by_type__link_clicks  1.031179
# 1   ext_table1_consumptions_by_type__other_clicks -0.007453
# 2                 ext_table1_reactions_like_total -0.048117
# 3      ext_table1_stories_by_action_type__comment -0.025475
# 4         ext_table1_stories_by_action_type__like  0.042213
# 5        ext_table1_stories_by_action_type__share  0.029720
# 6                          ext_table1_engaged_fan -0.052833
# 7                            ext_table1_fan_reach  1.132193
# 8                          ext_table1_impressions -0.451289
# 9                      ext_table1_impressions_fan -0.659907
# 10                                  BuzzFeed Quiz -0.001313
# 11                                 BuzzFeed Japan -0.004423
# 12                                    BuzzFeed UK -0.000179
# 13                                BuzzFeed Brasil -0.003197
# 14                            BuzzFeed Japan News -0.003400
# 15                           BuzzFeed Deutschland -0.000941
# 16                                  BuzzFeed News -0.000653
# 17                                       BuzzFeed  0.001055
# 18                                BuzzFeed Canada  0.001103
# 19                                 BuzzFeed Video -0.000889
# 20                                   Cocoa Butter  0.000389
# 21                           BuzzFeed Oz Politics  0.001970
# 22                             Quizzes En Español  0.002533
# 23                           Obsessed by BuzzFeed  0.000078
# 24                               BuzzFeed News BR -0.000238
# 25                                    Buy Me That  0.001259
# 26                           BuzzFeed UK Politics  0.002110
# 27                             BuzzFeed Australia -0.001365
# 28                                BuzzFeed Rewind -0.000909
# 29                              BuzzFeed Ladylike -0.000280
# ..                                            ...       ...
# 68                              BuzzFeed Open Lab  0.003500
# 69                                  BuzzFeed Tech  0.001164
# 70                               BuzzFeed Science -0.002026
# 71                               Reasons to Smile -0.000322
# 72                                     Tasty Miam  0.007113
# 73                                   Proper Tasty -0.004527
# 74                         BuzzFeed San Francisco -0.000189
# 75                                 BuzzFeed Shane  0.000953
# 76                                  BuzzFeed Ryan  0.000965
# 77                                          Nifty -0.003091
# 78                    See Something Say Something  0.002282
# 79                                    Tasty Japan  0.001567
# 80                                  BuzzFeed Zack  0.003303
# 81                                Kristin Chirico -0.002214
# 82                                BuzzFeed Austin  0.006416
# 83                                     Adam Ellis -0.002256
# 84                                  Another Round  0.001604
# 85                                       Top Knot -0.003070
# 86                                    Buzzed Feed -0.001247
# 87                                   BuzzFeed BFF -0.000315
# 88                                  Tasty One-Pot  0.002421
# 89                                BuzzFeed Sweaty  0.000705
# 90                                   Tasty Junior -0.000512
# 91                        Oh Great, More Politics  0.001655
# 92                                  Einfach Tasty  0.000524
# 93                             BuzzFeed Steven L. -0.002849
# 94                                   The Try Guys  0.002754
# 95                                   Ohmygod Yaaa  0.001248
# 96                                 BuzzFeed Chloe -0.006860
# 97                                  Nifty Science  0.000480
#
# [98 rows x 2 columns]

# %%
train[train['buzz_account_display_name'] == 'BuzzFeed']
# Out:
#                     buzz_external_id  buzz_post_parent_external_id  \
# 7      21898300328_10156148388685329                           0.0
# 18     21898300328_10156148686725329                           0.0
# 33     21898300328_10156148931050329                           0.0
# 38     21898300328_10156149479035329                           0.0
# 47     21898300328_10156148862845329                           0.0
# 56     21898300328_10156146864715329                           0.0
# 69     21898300328_10156149131140329                           0.0
# 92     21898300328_10156149119945329                           0.0
# 101    21898300328_10156148968950329                           0.0
# 120    21898300328_10156148798095329                           0.0
# 132    21898300328_10156148527055329                           0.0
# 152    21898300328_10156148417375329                           0.0
# 163    21898300328_10156148319630329                           0.0
# 184    21898300328_10156147181655329                           0.0
# 202    21898300328_10156147155190329                           0.0
# 207    21898300328_10156146790060329                           0.0
# 212    21898300328_10156146590075329                           0.0
# 218    21898300328_10156146780715329                           0.0
# 228    21898300328_10156146722385329                           0.0
# 249    21898300328_10156145316425329                           0.0
# 258    21898300328_10156145308715329                           0.0
# 264    21898300328_10156140843685329                           0.0
# 277    21898300328_10156144903860329                           0.0
# 292    21898300328_10156146087380329                           0.0
# 301    21898300328_10156136786250329                           0.0
# 312    21898300328_10156146128610329                           0.0
# 326    21898300328_10156146099010329                           0.0
# 341    21898300328_10156146043990329                           0.0
# 346    21898300328_10156145911415329                           0.0
# 356    21898300328_10156145835035329                           0.0
# ...                              ...                           ...
# 36948  21898300328_10155709727050329                           0.0
# 36960  21898300328_10155710265765329                           0.0
train = train.fillna(0)

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)


plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)

plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())
###get coefficients
import numpy as np
print(pd.concat([pd.DataFrame(df.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1))
# Out:
# WITH cross-promotion features
# Testing for shares!
# (2603, 98) (2603,)
# (651, 98) (651,)
# Predict  share
# Trial run - Score: 0.818149361141
# Cross-validated scores: [ 0.80566465  0.82223188  0.80015235  0.79552736  0.91301551  0.91698795
#   0.87862714  0.90964082  0.074587    0.829707  ]
# Mean accuracy =  0.774614166082
# Cross-Predicted Accuracy (R2): 0.743453252854
# Mean Absolute Error:  372.865891602
# Mean values:  987.520897357099  | percent error:  0.37757772276
# Testing for clicks!
# (2603, 98) (2603,)
# (651, 98) (651,)
# Predict  clicks
# Trial run - Score: 0.831687785346
# Cross-validated scores: [ 0.83168921  0.86599724  0.80201228  0.86318146  0.8896297   0.89032691
#   0.82136867  0.85483969 -0.75253483  0.72880278]
# Mean accuracy =  0.679531310677
# Cross-Predicted Accuracy (R2): 0.710680312002
# Mean Absolute Error:  33608.1092046
# Mean values:  113261.5331899201  | percent error:  0.296730127679
#                                                 0             0
# 0    ext_table1_consumptions_by_type__link_clicks  1.781964e+00
# 1   ext_table1_consumptions_by_type__other_clicks -1.828720e+00
# 2                 ext_table1_reactions_like_total  1.306102e+01
# 3      ext_table1_stories_by_action_type__comment  1.031499e+01
# 4         ext_table1_stories_by_action_type__like -8.176874e+00
# 5        ext_table1_stories_by_action_type__share  3.280250e+01
# 6                          ext_table1_engaged_fan  3.239254e+00
# 7                            ext_table1_fan_reach  1.523761e+00
# 8                          ext_table1_impressions -6.528294e-02
# 9                      ext_table1_impressions_fan -1.107128e+00
# 10                                  BuzzFeed Quiz -2.892258e+01
# 11                                 BuzzFeed Japan  1.936601e+02
# 12                                    BuzzFeed UK -4.804502e+01
# 13                                BuzzFeed Brasil  1.936601e+02
# 14                            BuzzFeed Japan News  1.818989e-11
# 15                           BuzzFeed Deutschland  1.573076e+02
# 16                                  BuzzFeed News  9.161360e+01
# 17                                       BuzzFeed  3.193757e+03
# 18                                BuzzFeed Canada -1.309198e+02
# 19                                 BuzzFeed Video -7.717188e+01
# 20                                   Cocoa Butter  9.449672e+00
# 21                           BuzzFeed Oz Politics  1.459335e+02
# 22                             Quizzes En Español -9.890755e-12
# 23                           Obsessed by BuzzFeed -8.012532e+01
# 24                               BuzzFeed News BR -1.364242e-12
# 25                                    Buy Me That  1.346982e+01
# 26                           BuzzFeed UK Politics  1.879919e+01
# 27                             BuzzFeed Australia -7.569471e+01
# 28                                BuzzFeed Rewind  9.958431e+00
# 29                              BuzzFeed Ladylike -7.421575e+01
# ..                                            ...           ...
# 68                              BuzzFeed Open Lab  0.000000e+00
# 69                                  BuzzFeed Tech -1.319764e+02
# 70                               BuzzFeed Science -2.382923e+02
# 71                               Reasons to Smile  0.000000e+00
# 72                                     Tasty Miam  0.000000e+00
# 73                                   Proper Tasty  0.000000e+00
# 74                         BuzzFeed San Francisco  1.855942e+02
# 75                                 BuzzFeed Shane  0.000000e+00
# 76                                  BuzzFeed Ryan  0.000000e+00
# 77                                          Nifty  1.003481e+02
# 78                    See Something Say Something  0.000000e+00
# 79                                    Tasty Japan  0.000000e+00
# 80                                  BuzzFeed Zack  0.000000e+00
# 81                                Kristin Chirico -1.007665e+02
# 82                                BuzzFeed Austin  0.000000e+00
# 83                                     Adam Ellis  0.000000e+00
# 84                                  Another Round  0.000000e+00
# 85                                       Top Knot  0.000000e+00
# 86                                    Buzzed Feed  0.000000e+00
# 87                                   BuzzFeed BFF  5.943440e+02
# 88                                  Tasty One-Pot  0.000000e+00
# 89                                BuzzFeed Sweaty  0.000000e+00
# 90                                   Tasty Junior  2.458866e+02
# 91                        Oh Great, More Politics  0.000000e+00
# 92                                  Einfach Tasty  0.000000e+00
# 93                             BuzzFeed Steven L.  0.000000e+00
# 94                                   The Try Guys -2.530666e+02
# 95                                   Ohmygod Yaaa  0.000000e+00
# 96                                 BuzzFeed Chloe  0.000000e+00
# 97                                  Nifty Science  0.000000e+00
#
# [98 rows x 2 columns]

# %%
###fit the regression on data points posted to a PAGE - pages-specific!

import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
############ LOG SCALING - 
###PREDICTION TASK - with cross-promotion
###Cross-validation
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
train = train[train['buzz_account_display_name'] == 'Tasty']
train = train.fillna(0)

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)


plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)

plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())
###get coefficients
import numpy as np
print(pd.concat([pd.DataFrame(df.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1))
# Out:
# WITH cross-promotion features
# Testing for shares!
# (192, 98) (192,)
# (48, 98) (48,)
# Predict  share
# Trial run - Score: 0.0129022587749
# Cross-validated scores: [-1.52620074  0.74654783  0.60650851  0.93828765  0.90267358  0.83184512
#   0.29420431  0.96580435 -2.24187976  0.50052195]
# Mean accuracy =  0.201831280042
# Cross-Predicted Accuracy (R2): 0.82558362152
# Mean Absolute Error:  1177.37814994
# Mean values:  2591.3791666666666  | percent error:  0.45434422144
# Testing for clicks!
# (192, 98) (192,)
# (48, 98) (48,)
# Predict  clicks
# Trial run - Score: 0.821674984327
# Cross-validated scores: [-0.6904606   0.79888341  0.88095447  0.77138002  0.84044088  0.02223771
#   0.83746041  0.69767728 -2.17909958  0.94026776]
# Mean accuracy =  0.291974174178
# Cross-Predicted Accuracy (R2): 0.688896257073
# Mean Absolute Error:  84535.5084971
# Mean values:  410603.39166666666  | percent error:  0.20588117442
#                                                 0             0
# 0    ext_table1_consumptions_by_type__link_clicks  1.051264e+00
# 1   ext_table1_consumptions_by_type__other_clicks -3.742169e+00
# 2                 ext_table1_reactions_like_total  6.555549e+01
# 3      ext_table1_stories_by_action_type__comment  1.988799e+01
# 4         ext_table1_stories_by_action_type__like -3.794946e+01
# 5        ext_table1_stories_by_action_type__share  3.889937e+00
# 6                          ext_table1_engaged_fan  3.798140e+00
# 7                            ext_table1_fan_reach  3.893679e-01
# 8                          ext_table1_impressions -3.118390e-01
# 9                      ext_table1_impressions_fan  1.171267e-03
# 10                                  BuzzFeed Quiz  1.010369e+02
# 11                                 BuzzFeed Japan -1.264766e-12
# 12                                    BuzzFeed UK -2.842553e+02
# 13                                BuzzFeed Brasil  2.222578e-11
# 14                            BuzzFeed Japan News  3.865352e-12
# 15                           BuzzFeed Deutschland -1.085709e-11
# 16                                  BuzzFeed News  3.617925e+02
# 17                                       BuzzFeed -9.749529e+01
# 18                                BuzzFeed Canada -5.652846e+02
# 19                                 BuzzFeed Video -4.341386e+02
# 20                                   Cocoa Butter  2.442935e+02
# 21                           BuzzFeed Oz Politics  3.740297e-11
# 22                             Quizzes En Español  1.006129e-11
# 23                           Obsessed by BuzzFeed -1.486634e+03
# 24                               BuzzFeed News BR -1.438138e-11
# 25                                    Buy Me That  6.260766e+02
# 26                           BuzzFeed UK Politics -8.014922e-12
# 27                             BuzzFeed Australia -8.018684e+02
# 28                                BuzzFeed Rewind -5.677225e+02
# 29                              BuzzFeed Ladylike  1.449424e+03
# ..                                            ...           ...
# 68                              BuzzFeed Open Lab  0.000000e+00
# 69                                  BuzzFeed Tech  0.000000e+00
# 70                               BuzzFeed Science  0.000000e+00
# 71                               Reasons to Smile  0.000000e+00
# 72                                     Tasty Miam  0.000000e+00
# 73                                   Proper Tasty -3.288033e+03
# 74                         BuzzFeed San Francisco  0.000000e+00
# 75                                 BuzzFeed Shane  0.000000e+00
# 76                                  BuzzFeed Ryan  0.000000e+00
# 77                                          Nifty  0.000000e+00
# 78                    See Something Say Something  0.000000e+00
# 79                                    Tasty Japan  0.000000e+00
# 80                                  BuzzFeed Zack  0.000000e+00
# 81                                Kristin Chirico  0.000000e+00
# 82                                BuzzFeed Austin  0.000000e+00
# 83                                     Adam Ellis  0.000000e+00
# 84                                  Another Round  0.000000e+00
# 85                                       Top Knot  0.000000e+00
# 86                                    Buzzed Feed  0.000000e+00
# 87                                   BuzzFeed BFF  0.000000e+00
# 88                                  Tasty One-Pot -1.375325e+03
# 89                                BuzzFeed Sweaty  0.000000e+00
# 90                                   Tasty Junior  0.000000e+00
# 91                        Oh Great, More Politics  0.000000e+00
# 92                                  Einfach Tasty  0.000000e+00
# 93                             BuzzFeed Steven L.  0.000000e+00
# 94                                   The Try Guys  0.000000e+00
# 95                                   Ohmygod Yaaa  0.000000e+00
# 96                                 BuzzFeed Chloe  0.000000e+00
# 97                                  Nifty Science  0.000000e+00
#
# [98 rows x 2 columns]

# %%
###BUCKETS - REGRESS

# %%
###fit the regression on data points posted to a PAGE - pages-specific!

import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline
############ LOG SCALING - 
###PREDICTION TASK - with cross-promotion
###Cross-validation
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]


train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)).astype(int)
train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1)).astype(int)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']

metric = 'share'
# metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)


plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())

# metric = 'share'
metric = 'clicks'

if metric == 'share':
    y = y_share
    print("Testing for shares!")
else:
    y = y_clicks
    print("Testing for clicks!")

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)


## The line / model
plt.scatter(y_test, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()

print("Predict ", metric)
print("Trial run - Score:", model.score(X_test, y_test))

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
scores = cross_val_score(model, df, y, cv = 10)
print("Cross-validated scores:", scores)
print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y, cv=10)

plt.scatter(y, predictions)

accuracy = metrics.r2_score(y, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
print("Mean values: ", y.mean(), " | percent error: ",  mean_absolute_error(y, predictions)/y.mean())
###get coefficients
import numpy as np
print(pd.concat([pd.DataFrame(df.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1))
# Out:
# WITH cross-promotion features
# Testing for shares!
# (29784, 98) (29784,)
# (7447, 98) (7447,)
# Predict  share
# Trial run - Score: 0.485747508319
# Cross-validated scores: [ 0.54154521  0.46404504  0.48949377  0.4950984   0.48840946  0.30304319
#   0.49475968  0.4370749   0.49360896  0.48404475]
# Mean accuracy =  0.469112335752
# Cross-Predicted Accuracy (R2): 0.469497820597
# Mean Absolute Error:  1.16108507045
# Mean values:  3.207058633934087  | percent error:  0.362040487243
# Testing for clicks!
# (29784, 98) (29784,)
# (7447, 98) (7447,)
# Predict  clicks
# Trial run - Score: 0.484047606958
# Cross-validated scores: [ 0.54640749  0.48482051  0.49999799  0.54478423  0.47811075  0.0488197
#   0.52489607  0.50785786  0.56833162  0.56132391]
# Mean accuracy =  0.476535013203
# Cross-Predicted Accuracy (R2): 0.437630166894
# Mean Absolute Error:  1.2543063548
# Mean values:  7.869490478364804  | percent error:  0.159388509109
#                                                 0             0
# 0    ext_table1_consumptions_by_type__link_clicks -3.109665e-05
# 1   ext_table1_consumptions_by_type__other_clicks -6.904802e-05
# 2                 ext_table1_reactions_like_total  1.702121e-04
# 3      ext_table1_stories_by_action_type__comment  5.701734e-04
# 4         ext_table1_stories_by_action_type__like  1.340502e-04
# 5        ext_table1_stories_by_action_type__share -9.699968e-05
# 6                          ext_table1_engaged_fan  9.256481e-05
# 7                            ext_table1_fan_reach  9.994444e-06
# 8                          ext_table1_impressions -3.173509e-06
# 9                      ext_table1_impressions_fan -3.942902e-06
# 10                                  BuzzFeed Quiz -1.186508e-02
# 11                                 BuzzFeed Japan  8.342654e-03
# 12                                    BuzzFeed UK -5.796625e-03
# 13                                BuzzFeed Brasil -1.781904e-02
# 14                            BuzzFeed Japan News  2.142358e-02
# 15                           BuzzFeed Deutschland -1.069374e-02
# 16                                  BuzzFeed News -4.269820e-03
# 17                                       BuzzFeed -2.844914e-03
# 18                                BuzzFeed Canada  6.462997e-03
# 19                                 BuzzFeed Video -5.852808e-03
# 20                                   Cocoa Butter  3.503963e-03
# 21                           BuzzFeed Oz Politics  1.464781e-02
# 22                             Quizzes En Español -7.415323e-04
# 23                           Obsessed by BuzzFeed  1.501371e-03
# 24                               BuzzFeed News BR  2.451162e-02
# 25                                    Buy Me That  1.268538e-03
# 26                           BuzzFeed UK Politics  2.020305e-02
# 27                             BuzzFeed Australia -6.647712e-03
# 28                                BuzzFeed Rewind -4.597102e-03
# 29                              BuzzFeed Ladylike -5.192796e-04
# ..                                            ...           ...
# 68                              BuzzFeed Open Lab  4.360789e-02
# 69                                  BuzzFeed Tech  2.229639e-02
# 70                               BuzzFeed Science  7.406997e-03
# 71                               Reasons to Smile  5.445905e-03
# 72                                     Tasty Miam -4.239598e-03
# 73                                   Proper Tasty -1.751729e-02
# 74                         BuzzFeed San Francisco  2.008628e-02
# 75                                 BuzzFeed Shane  9.198195e-03
# 76                                  BuzzFeed Ryan  9.305151e-03
# 77                                          Nifty -1.047434e-02
# 78                    See Something Say Something  3.571008e-02
# 79                                    Tasty Japan -8.351763e-03
# 80                                  BuzzFeed Zack  8.380300e-03
# 81                                Kristin Chirico -1.684874e-02
# 82                                BuzzFeed Austin  3.174624e-02
# 83                                     Adam Ellis -6.545343e-03
# 84                                  Another Round  8.236515e-03
# 85                                       Top Knot -9.464669e-03
# 86                                    Buzzed Feed  3.892851e-03
# 87                                   BuzzFeed BFF  2.515829e-03
# 88                                  Tasty One-Pot -4.704611e-03
# 89                                BuzzFeed Sweaty  1.578606e-02
# 90                                   Tasty Junior -5.277659e-03
# 91                        Oh Great, More Politics  1.274706e-02
# 92                                  Einfach Tasty -3.623316e-03
# 93                             BuzzFeed Steven L. -6.938894e-18
# 94                                   The Try Guys  1.917230e-02
# 95                                   Ohmygod Yaaa  1.028399e-03
# 96                                 BuzzFeed Chloe  1.140436e-02
# 97                                  Nifty Science  0.000000e+00
#
# [98 rows x 2 columns]

# %%
train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)/np.log(100)).astype(int)
train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1)/np.log(100)).astype(int)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

# %%
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']
print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

###log-scaling
for feat in features:
    train[feat] = np.log(train[feat] + 1)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1))
train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1))
# train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)).astype(int)
# train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1)).astype(int)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']

print('SHARES!')
res = ols(y = y_share, x = train[features])
print(res)

print('CLICKS!')
res = ols(y = y_clicks, x = train[features])
print(res)
# Out:
# WITH cross-promotion features
# SHARES!
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <ext_table1_consumptions_by_type__link_clicks>
#              + <ext_table1_consumptions_by_type__other_clicks> + <ext_table1_reactions_like_total>
#              + <ext_table1_stories_by_action_type__comment>
#              + <ext_table1_stories_by_action_type__like> + <ext_table1_stories_by_action_type__share>
#              + <ext_table1_engaged_fan> + <ext_table1_fan_reach>
#              + <ext_table1_impressions> + <ext_table1_impressions_fan> + <BuzzFeed Quiz>
#              + <BuzzFeed Japan> + <BuzzFeed UK> + <BuzzFeed Brasil> + <BuzzFeed Japan News>
#              + <BuzzFeed Deutschland> + <BuzzFeed News> + <BuzzFeed>
#              + <BuzzFeed Canada> + <BuzzFeed Video> + <Cocoa Butter>
#              + <BuzzFeed Oz Politics> + <Quizzes En Español> + <Obsessed by BuzzFeed>
#              + <BuzzFeed News BR> + <Buy Me That> + <BuzzFeed UK Politics> + <BuzzFeed Australia>
#              + <BuzzFeed Rewind> + <BuzzFeed Ladylike> + <BuzzFeed Books>
#              + <BuzzFeed DIY> + <BuzzFeed México> + <BuzzFeed Food> + <BuzzFeed Celeb>
#              + <BuzzFeed Animals> + <BuzzFeed France> + <BuzzFeed Español>
#              + <BuzzFeed Style> + <Tasty> + <Cheeky> + <BuzzFeed Community>
#              + <BuzzFeed Weddings> + <Tasty Demais> + <BuzzFeed World> + <SOML>
#              + <BuzzFeed Entertainment> + <BuzzFeed Geeky> + <BuzzFeed Parents>
#              + <BuzzFeed Health> + <BuzzFeed España> + <BuzzFeed Politics> + <Pero Like>
#              + <BuzzFeed UK News> + <BuzzFeed India> + <BuzzFeed France News>
#              + <BuzzFeed Scotland> + <LOLA> + <BuzzFeed Philippines> + <BuzzFeed Oz News>
#              + <BuzzFeed Unsolved> + <BuzzFeed IRL> + <Bien Tasty>
#              + <BuzzFeed Reader> + <BuzzFeed Pink> + <BuzzFeed LGBT> + <BuzzFeed Partner>
#              + <So Relatable> + <BuzzFeed Open Lab> + <BuzzFeed Tech>
#              + <BuzzFeed Science> + <Reasons to Smile> + <Tasty Miam> + <Proper Tasty>
#              + <BuzzFeed San Francisco> + <BuzzFeed Shane> + <BuzzFeed Ryan> + <Nifty>
#              + <See Something Say Something> + <Tasty Japan> + <BuzzFeed Zack>
#              + <Kristin Chirico> + <BuzzFeed Austin> + <Adam Ellis> + <Another Round>
#              + <Top Knot> + <Buzzed Feed> + <BuzzFeed BFF> + <Tasty One-Pot>
#              + <BuzzFeed Sweaty> + <Tasty Junior> + <Oh Great, More Politics>
#              + <Einfach Tasty> + <BuzzFeed Steven L.> + <The Try Guys> + <Ohmygod Yaaa>
#              + <BuzzFeed Chloe> + <Nifty Science> + <intercept>
#
# Number of Observations:         37231
# Number of Degrees of Freedom:   98
#
# R-squared:         0.9071
# Adj R-squared:     0.9069
#
# Rmse:              0.6294
#
# F-stat (98, 37133):  3738.5672, p-value:     0.0000
#
# Degrees of Freedom: model 97, resid 37133
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ext_table1_consumptions_by_type__link_clicks     0.1398     0.0176       7.94     0.0000     0.1053     0.1743
# ext_table1_consumptions_by_type__other_clicks     0.0043     0.0069       0.62     0.5355    -0.0093     0.0178
# ext_table1_reactions_like_total    -0.1022     0.0145      -7.03     0.0000    -0.1307    -0.0737
# ext_table1_stories_by_action_type__comment     0.0168     0.0044       3.82     0.0001     0.0082     0.0254
# ext_table1_stories_by_action_type__like     0.3400     0.0159      21.37     0.0000     0.3088     0.3712
# --------------------------------------------------------------------------------
# ext_table1_stories_by_action_type__share     0.8506     0.0054     158.38     0.0000     0.8401     0.8612
# ext_table1_engaged_fan    -0.1077     0.0237      -4.55     0.0000    -0.1541    -0.0612
# ext_table1_fan_reach     1.2498     0.0468      26.68     0.0000     1.1579     1.3416
# ext_table1_impressions    -0.3972     0.0193     -20.57     0.0000    -0.4350    -0.3594
# ext_table1_impressions_fan    -0.8872     0.0494     -17.97     0.0000    -0.9840    -0.7904
# --------------------------------------------------------------------------------
#  BuzzFeed Quiz     0.0008     0.0002       5.20     0.0000     0.0005     0.0011
# BuzzFeed Japan    -0.0030     0.0002     -12.54     0.0000    -0.0034    -0.0025
#    BuzzFeed UK    -0.0005     0.0001      -3.75     0.0002    -0.0007    -0.0002
# BuzzFeed Brasil    -0.0022     0.0002      -9.43     0.0000    -0.0027    -0.0018
# BuzzFeed Japan News    -0.0029     0.0003      -9.93     0.0000    -0.0035    -0.0024
# --------------------------------------------------------------------------------
# BuzzFeed Deutschland    -0.0015     0.0003      -5.01     0.0000    -0.0021    -0.0009
#  BuzzFeed News    -0.0002     0.0001      -1.20     0.2315    -0.0004     0.0001
#       BuzzFeed     0.0007     0.0001       6.67     0.0000     0.0005     0.0009
# BuzzFeed Canada     0.0003     0.0002       1.62     0.1047    -0.0001     0.0007
# BuzzFeed Video    -0.0003     0.0001      -2.48     0.0130    -0.0006    -0.0001
# --------------------------------------------------------------------------------
#   Cocoa Butter    -0.0004     0.0002      -2.08     0.0375    -0.0007    -0.0000
# BuzzFeed Oz Politics     0.0013     0.0003       4.29     0.0000     0.0007     0.0019
# Quizzes En Español     0.0019     0.0003       5.64     0.0000     0.0012     0.0025
# Obsessed by BuzzFeed     0.0006     0.0002       3.98     0.0001     0.0003     0.0009
# --------------------------------------------------------------------------------
#   Tasty Junior    -0.0030     0.0025      -1.17     0.2415    -0.0080     0.0020
# Oh Great, More Politics    -0.0030     0.0042      -0.72     0.4689    -0.0112     0.0051
#  Einfach Tasty    -0.0019     0.0023      -0.85     0.3959    -0.0064     0.0025
# BuzzFeed Steven L.     0.0003     0.0072       0.04     0.9688    -0.0137     0.0143
#   The Try Guys    -0.0013     0.0032      -0.42     0.6780    -0.0077     0.0050
# --------------------------------------------------------------------------------
#   Ohmygod Yaaa     0.0017     0.0042       0.40     0.6872    -0.0065     0.0099
# BuzzFeed Chloe    -0.0031     0.0072      -0.44     0.6615    -0.0172     0.0109
#  Nifty Science    -0.0004     0.0072      -0.06     0.9556    -0.0144     0.0136
#      intercept     5.4129  3986.0765       0.00     0.9989 -7807.2972  7818.1229
# ---------------------------------End of Summary---------------------------------
#
# CLICKS!
#
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <ext_table1_consumptions_by_type__link_clicks>
#              + <ext_table1_consumptions_by_type__other_clicks> + <ext_table1_reactions_like_total>
#              + <ext_table1_stories_by_action_type__comment>
#              + <ext_table1_stories_by_action_type__like> + <ext_table1_stories_by_action_type__share>
#              + <ext_table1_engaged_fan> + <ext_table1_fan_reach>
#              + <ext_table1_impressions> + <ext_table1_impressions_fan> + <BuzzFeed Quiz>
#              + <BuzzFeed Japan> + <BuzzFeed UK> + <BuzzFeed Brasil> + <BuzzFeed Japan News>
#              + <BuzzFeed Deutschland> + <BuzzFeed News> + <BuzzFeed>
#              + <BuzzFeed Canada> + <BuzzFeed Video> + <Cocoa Butter>
#              + <BuzzFeed Oz Politics> + <Quizzes En Español> + <Obsessed by BuzzFeed>
#              + <BuzzFeed News BR> + <Buy Me That> + <BuzzFeed UK Politics> + <BuzzFeed Australia>
#              + <BuzzFeed Rewind> + <BuzzFeed Ladylike> + <BuzzFeed Books>
#              + <BuzzFeed DIY> + <BuzzFeed México> + <BuzzFeed Food> + <BuzzFeed Celeb>
#              + <BuzzFeed Animals> + <BuzzFeed France> + <BuzzFeed Español>
#              + <BuzzFeed Style> + <Tasty> + <Cheeky> + <BuzzFeed Community>
#              + <BuzzFeed Weddings> + <Tasty Demais> + <BuzzFeed World> + <SOML>
#              + <BuzzFeed Entertainment> + <BuzzFeed Geeky> + <BuzzFeed Parents>
#              + <BuzzFeed Health> + <BuzzFeed España> + <BuzzFeed Politics> + <Pero Like>
#              + <BuzzFeed UK News> + <BuzzFeed India> + <BuzzFeed France News>
#              + <BuzzFeed Scotland> + <LOLA> + <BuzzFeed Philippines> + <BuzzFeed Oz News>
#              + <BuzzFeed Unsolved> + <BuzzFeed IRL> + <Bien Tasty>
#              + <BuzzFeed Reader> + <BuzzFeed Pink> + <BuzzFeed LGBT> + <BuzzFeed Partner>
#              + <So Relatable> + <BuzzFeed Open Lab> + <BuzzFeed Tech>
#              + <BuzzFeed Science> + <Reasons to Smile> + <Tasty Miam> + <Proper Tasty>
#              + <BuzzFeed San Francisco> + <BuzzFeed Shane> + <BuzzFeed Ryan> + <Nifty>
#              + <See Something Say Something> + <Tasty Japan> + <BuzzFeed Zack>
#              + <Kristin Chirico> + <BuzzFeed Austin> + <Adam Ellis> + <Another Round>
#              + <Top Knot> + <Buzzed Feed> + <BuzzFeed BFF> + <Tasty One-Pot>
#              + <BuzzFeed Sweaty> + <Tasty Junior> + <Oh Great, More Politics>
#              + <Einfach Tasty> + <BuzzFeed Steven L.> + <The Try Guys> + <Ohmygod Yaaa>
#              + <BuzzFeed Chloe> + <Nifty Science> + <intercept>
#
# Number of Observations:         37231
# Number of Degrees of Freedom:   98
#
# R-squared:         0.9165
# Adj R-squared:     0.9163
#
# Rmse:              0.6990
#
# F-stat (98, 37133):  4200.7275, p-value:     0.0000
#
# Degrees of Freedom: model 97, resid 37133
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ext_table1_consumptions_by_type__link_clicks     1.0356     0.0196      52.93     0.0000     0.9972     1.0739
# ext_table1_consumptions_by_type__other_clicks    -0.0035     0.0077      -0.45     0.6521    -0.0185     0.0116
# ext_table1_reactions_like_total    -0.0436     0.0161      -2.70     0.0069    -0.0752    -0.0120
# ext_table1_stories_by_action_type__comment    -0.0259     0.0049      -5.29     0.0000    -0.0354    -0.0163
# ext_table1_stories_by_action_type__like     0.0373     0.0177       2.11     0.0349     0.0027     0.0719
# --------------------------------------------------------------------------------
# ext_table1_stories_by_action_type__share     0.0269     0.0060       4.50     0.0000     0.0152     0.0385
# ext_table1_engaged_fan    -0.0683     0.0263      -2.59     0.0095    -0.1198    -0.0167
# ext_table1_fan_reach     1.2114     0.0520      23.28     0.0000     1.1094     1.3134
# ext_table1_impressions    -0.4416     0.0214     -20.60     0.0000    -0.4837    -0.3996
# ext_table1_impressions_fan    -0.7356     0.0548     -13.41     0.0000    -0.8431    -0.6281
# --------------------------------------------------------------------------------
#  BuzzFeed Quiz    -0.0013     0.0002      -7.77     0.0000    -0.0017    -0.0010
# BuzzFeed Japan    -0.0044     0.0003     -16.86     0.0000    -0.0049    -0.0039
#    BuzzFeed UK    -0.0002     0.0001      -1.15     0.2497    -0.0004     0.0001
# BuzzFeed Brasil    -0.0032     0.0003     -12.19     0.0000    -0.0037    -0.0027
# BuzzFeed Japan News    -0.0038     0.0003     -11.44     0.0000    -0.0044    -0.0031
# --------------------------------------------------------------------------------
# BuzzFeed Deutschland    -0.0007     0.0003      -1.99     0.0461    -0.0013    -0.0000
#  BuzzFeed News    -0.0006     0.0002      -4.21     0.0000    -0.0009    -0.0003
#       BuzzFeed     0.0010     0.0001       8.26     0.0000     0.0007     0.0012
# BuzzFeed Canada     0.0010     0.0002       4.95     0.0000     0.0006     0.0014
# BuzzFeed Video    -0.0009     0.0002      -5.67     0.0000    -0.0012    -0.0006
# --------------------------------------------------------------------------------
#   Cocoa Butter     0.0002     0.0002       1.24     0.2149    -0.0001     0.0006
#  Tasty One-Pot     0.0022     0.0027       0.80     0.4231    -0.0032     0.0076
# BuzzFeed Sweaty     0.0005     0.0018       0.28     0.7817    -0.0031     0.0041
# --------------------------------------------------------------------------------
#   Tasty Junior    -0.0019     0.0028      -0.67     0.5031    -0.0074     0.0036
# Oh Great, More Politics     0.0013     0.0046       0.29     0.7751    -0.0077     0.0104
#  Einfach Tasty     0.0004     0.0025       0.14     0.8851    -0.0046     0.0053
# BuzzFeed Steven L.    -0.0031     0.0079      -0.38     0.7010    -0.0186     0.0125
#   The Try Guys     0.0013     0.0036       0.35     0.7247    -0.0058     0.0083
# --------------------------------------------------------------------------------
#   Ohmygod Yaaa     0.0034     0.0046       0.73     0.4668    -0.0057     0.0125
# BuzzFeed Chloe    -0.0071     0.0079      -0.89     0.3733    -0.0226     0.0085
#  Nifty Science     0.0004     0.0079       0.05     0.9614    -0.0152     0.0160
#      intercept     3.5850  4427.2863       0.00     0.9994 -8673.8961  8681.0661
# ---------------------------------End of Summary---------------------------------

# %%
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]


train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)).astype(int)
train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1)).astype(int)

# y_clicks = train['clicks_bucket']
# y_share = train['share_bucket']

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

print('SHARES!')
res = ols(y = y_share, x = train[features])
print(res)

print('CLICKS!')
res = ols(y = y_clicks, x = train[features])
print(res)
# Out:
# WITHOUT cross-promotion features
# SHARES!
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <ext_table1_consumptions_by_type__link_clicks>
#              + <ext_table1_consumptions_by_type__other_clicks> + <ext_table1_reactions_like_total>
#              + <ext_table1_stories_by_action_type__comment>
#              + <ext_table1_stories_by_action_type__like> + <ext_table1_stories_by_action_type__share>
#              + <ext_table1_engaged_fan> + <ext_table1_fan_reach>
#              + <ext_table1_impressions> + <ext_table1_impressions_fan> + <BuzzFeed Quiz>
#              + <BuzzFeed Japan> + <BuzzFeed UK> + <BuzzFeed Brasil> + <BuzzFeed Japan News>
#              + <BuzzFeed Deutschland> + <BuzzFeed News> + <BuzzFeed>
#              + <BuzzFeed Canada> + <BuzzFeed Video> + <Cocoa Butter>
#              + <BuzzFeed Oz Politics> + <Quizzes En Español> + <Obsessed by BuzzFeed>
#              + <BuzzFeed News BR> + <Buy Me That> + <BuzzFeed UK Politics> + <BuzzFeed Australia>
#              + <BuzzFeed Rewind> + <BuzzFeed Ladylike> + <BuzzFeed Books>
#              + <BuzzFeed DIY> + <BuzzFeed México> + <BuzzFeed Food> + <BuzzFeed Celeb>
#              + <BuzzFeed Animals> + <BuzzFeed France> + <BuzzFeed Español>
#              + <BuzzFeed Style> + <Tasty> + <Cheeky> + <BuzzFeed Community>
#              + <BuzzFeed Weddings> + <Tasty Demais> + <BuzzFeed World> + <SOML>
#              + <BuzzFeed Entertainment> + <BuzzFeed Geeky> + <BuzzFeed Parents>
#              + <BuzzFeed Health> + <BuzzFeed España> + <BuzzFeed Politics> + <Pero Like>
#              + <BuzzFeed UK News> + <BuzzFeed India> + <BuzzFeed France News>
#              + <BuzzFeed Scotland> + <LOLA> + <BuzzFeed Philippines> + <BuzzFeed Oz News>
#              + <BuzzFeed Unsolved> + <BuzzFeed IRL> + <Bien Tasty>
#              + <BuzzFeed Reader> + <BuzzFeed Pink> + <BuzzFeed LGBT> + <BuzzFeed Partner>
#              + <So Relatable> + <BuzzFeed Open Lab> + <BuzzFeed Tech>
#              + <BuzzFeed Science> + <Reasons to Smile> + <Tasty Miam> + <Proper Tasty>
#              + <BuzzFeed San Francisco> + <BuzzFeed Shane> + <BuzzFeed Ryan> + <Nifty>
#              + <See Something Say Something> + <Tasty Japan> + <BuzzFeed Zack>
#              + <Kristin Chirico> + <BuzzFeed Austin> + <Adam Ellis> + <Another Round>
#              + <Top Knot> + <Buzzed Feed> + <BuzzFeed BFF> + <Tasty One-Pot>
#              + <BuzzFeed Sweaty> + <Tasty Junior> + <Oh Great, More Politics>
#              + <Einfach Tasty> + <BuzzFeed Steven L.> + <The Try Guys> + <Ohmygod Yaaa>
#              + <BuzzFeed Chloe> + <Nifty Science> + <intercept>
#
# Number of Observations:         37231
# Number of Degrees of Freedom:   98
#
# R-squared:         0.7704
# Adj R-squared:     0.7698
#
# Rmse:            494.7258
#
# F-stat (98, 37133):  1284.2197, p-value:     0.0000
#
# Degrees of Freedom: model 97, resid 37133
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ext_table1_consumptions_by_type__link_clicks     0.0252     0.0017      15.25     0.0000     0.0220     0.0285
# ext_table1_consumptions_by_type__other_clicks     0.0195     0.0017      11.65     0.0000     0.0162     0.0228
# ext_table1_reactions_like_total     0.2251     0.0131      17.25     0.0000     0.1996     0.2507
# ext_table1_stories_by_action_type__comment     0.0998     0.0140       7.11     0.0000     0.0723     0.1273
# ext_table1_stories_by_action_type__like    -0.0578     0.0098      -5.90     0.0000    -0.0770    -0.0386
# --------------------------------------------------------------------------------
# ext_table1_stories_by_action_type__share     4.4435     0.0226     196.88     0.0000     4.3992     4.4877
# ext_table1_engaged_fan    -0.0211     0.0020     -10.63     0.0000    -0.0250    -0.0172
# ext_table1_fan_reach     0.0045     0.0001      43.73     0.0000     0.0043     0.0047
# ext_table1_impressions    -0.0106     0.0001     -92.14     0.0000    -0.0109    -0.0104
# ext_table1_impressions_fan     0.0074     0.0002      49.11     0.0000     0.0071     0.0077
# --------------------------------------------------------------------------------
#  BuzzFeed Quiz     0.5882     0.1082       5.44     0.0000     0.3761     0.8002
# BuzzFeed Japan    -0.0813     0.1791      -0.45     0.6498    -0.4324     0.2697
#    BuzzFeed UK    -0.1285     0.0933      -1.38     0.1685    -0.3114     0.0544
# BuzzFeed Brasil    -2.3057     0.1838     -12.55     0.0000    -2.6659    -1.9455
# BuzzFeed Japan News    -0.0683     0.2251      -0.30     0.7616    -0.5096     0.3730
# --------------------------------------------------------------------------------
# BuzzFeed Deutschland    -0.1556     0.2345      -0.66     0.5070    -0.6152     0.3040
#  BuzzFeed News     0.0306     0.1043       0.29     0.7691    -0.1737     0.2349
#       BuzzFeed     0.2877     0.0799       3.60     0.0003     0.1311     0.4443
# BuzzFeed Canada    -0.4435     0.1409      -3.15     0.0017    -0.7197    -0.1673
# BuzzFeed Video    -0.4440     0.1077      -4.12     0.0000    -0.6551    -0.2329
# --------------------------------------------------------------------------------
#   Cocoa Butter    -0.0967     0.1413      -0.68     0.4939    -0.3737     0.1803
# BuzzFeed Oz Politics    -0.1021     0.2344      -0.44     0.6633    -0.5616     0.3574
# Quizzes En Español    -0.4357     0.2543      -1.71     0.0867    -0.9343     0.0628
# Obsessed by BuzzFeed    -0.0605     0.1220      -0.50     0.6200    -0.2997     0.1787
# BuzzFeed News BR    -1.6765     0.3356      -5.00     0.0000    -2.3343    -1.0188
# --------------------------------------------------------------------------------
#    Buy Me That     0.2442     0.1605       1.52     0.1283    -0.0705     0.5588
# BuzzFeed UK Politics    -0.0322     0.2532      -0.13     0.8986    -0.5285     0.4640
# BuzzFeed Australia    -0.4623     0.0859      -5.38     0.0000    -0.6307    -0.2940
# BuzzFeed Rewind    -0.2443     0.1323      -1.85     0.0649    -0.5037     0.0151
# BuzzFeed Ladylike    -0.1948     0.2054      -0.95     0.3429    -0.5974     0.2078
# --------------------------------------------------------------------------------
# BuzzFeed Books    -0.3038     0.1358      -2.24     0.0252    -0.5699    -0.0377
#   BuzzFeed DIY    -0.2295     0.1443      -1.59     0.1119    -0.5124     0.0534
# BuzzFeed México    -0.1468     0.1917      -0.77     0.4439    -0.5226     0.2290
#  BuzzFeed Food     0.6144     0.1357       4.53     0.0000     0.3485     0.8803
# Formula: Y ~ <ext_table1_consumptions_by_type__link_clicks>
#              + <ext_table1_consumptions_by_type__other_clicks> + <ext_table1_reactions_like_total>
#              + <ext_table1_stories_by_action_type__comment>
#              + <ext_table1_stories_by_action_type__like> + <ext_table1_stories_by_action_type__share>
#              + <ext_table1_engaged_fan> + <ext_table1_fan_reach>
#              + <ext_table1_impressions> + <ext_table1_impressions_fan> + <BuzzFeed Quiz>
#              + <BuzzFeed Japan> + <BuzzFeed UK> + <BuzzFeed Brasil> + <BuzzFeed Japan News>
#              + <BuzzFeed Deutschland> + <BuzzFeed News> + <BuzzFeed>
#              + <BuzzFeed Canada> + <BuzzFeed Video> + <Cocoa Butter>
#              + <BuzzFeed Oz Politics> + <Quizzes En Español> + <Obsessed by BuzzFeed>
#              + <BuzzFeed News BR> + <Buy Me That> + <BuzzFeed UK Politics> + <BuzzFeed Australia>
#              + <BuzzFeed Rewind> + <BuzzFeed Ladylike> + <BuzzFeed Books>
#              + <BuzzFeed DIY> + <BuzzFeed México> + <BuzzFeed Food> + <BuzzFeed Celeb>
#              + <BuzzFeed Animals> + <BuzzFeed France> + <BuzzFeed Español>
#              + <BuzzFeed Style> + <Tasty> + <Cheeky> + <BuzzFeed Community>
#              + <BuzzFeed Weddings> + <Tasty Demais> + <BuzzFeed World> + <SOML>
#              + <BuzzFeed Entertainment> + <BuzzFeed Geeky> + <BuzzFeed Parents>
#              + <BuzzFeed Health> + <BuzzFeed España> + <BuzzFeed Politics> + <Pero Like>
#              + <BuzzFeed UK News> + <BuzzFeed India> + <BuzzFeed France News>
#              + <BuzzFeed Scotland> + <LOLA> + <BuzzFeed Philippines> + <BuzzFeed Oz News>
#              + <BuzzFeed Unsolved> + <BuzzFeed IRL> + <Bien Tasty>
#              + <BuzzFeed Reader> + <BuzzFeed Pink> + <BuzzFeed LGBT> + <BuzzFeed Partner>
#              + <So Relatable> + <BuzzFeed Open Lab> + <BuzzFeed Tech>
#              + <BuzzFeed Science> + <Reasons to Smile> + <Tasty Miam> + <Proper Tasty>
#              + <BuzzFeed San Francisco> + <BuzzFeed Shane> + <BuzzFeed Ryan> + <Nifty>
#              + <See Something Say Something> + <Tasty Japan> + <BuzzFeed Zack>
#              + <Kristin Chirico> + <BuzzFeed Austin> + <Adam Ellis> + <Another Round>
#              + <Top Knot> + <Buzzed Feed> + <BuzzFeed BFF> + <Tasty One-Pot>
#              + <BuzzFeed Sweaty> + <Tasty Junior> + <Oh Great, More Politics>
#              + <Einfach Tasty> + <BuzzFeed Steven L.> + <The Try Guys> + <Ohmygod Yaaa>
#              + <BuzzFeed Chloe> + <Nifty Science> + <intercept>
#
# Number of Observations:         37231
# Number of Degrees of Freedom:   98
#
# R-squared:         0.8820
# Adj R-squared:     0.8817
#
# Rmse:          23129.3152
#
# F-stat (98, 37133):  2860.7361, p-value:     0.0000
#
# Degrees of Freedom: model 97, resid 37133
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
# ---------------------------------End of Summary---------------------------------

# %%
#######REGRESSION AND PREDICTION: Page-wise performance:
###ALT
import pandas as pd
from pandas.stats.api import ols
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import math
# %matplotlib inline

from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

############ LOG SCALING - 
###PREDICTION TASK - with cross-promotion
###Cross-validation
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')

print("WITH cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

###convert to log-scale
for feat in features:
    train[feat] = np.log(train[feat]+1)

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

lm = linear_model.LinearRegression()
cv = 10

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

train['clicks_bucket'] = np.log(train['ext_twodays_consumptions_by_type__link_clicks'] + 1).astype(int)
train['share_bucket'] = np.log(train['ext_twodays_stories_by_action_type__share']+1).astype(int)

all_train = train

share_r2 = []
share_error = []
clicks_r2 = []
clicks_error = []
order_pages = []
len_samples = []

# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']
y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

###generate DFs for analysis - X and Y
df = train[features]

# fit a model
model = lm

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# 10-fold CV
# scores = cross_val_score(model, df, y_share, cv = 10)
# print("Cross-validated scores:", scores)
# print("Mean accuracy = ", scores.mean())

# Make cross validated predictions
predictions = cross_val_predict(model, df, y_share, cv=cv)

# plt.scatter(y, predictions)

accuracy = metrics.r2_score(y_share, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)
share_r2.append(accuracy)

from sklearn.metrics import mean_absolute_error
# print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
error_percent = mean_absolute_error(y_share, predictions)/y_share.mean()
print("Mean values: ", y_share.mean(), " | percent error: ",  error_percent)
share_error.append(error_percent)

model = lm

###prediction with cross validation
# Necessary imports: 
from sklearn.cross_validation import cross_val_score, cross_val_predict
from sklearn import metrics

# # 10-fold CV
# scores = cross_val_score(model, df, y_clicks, cv = 10)
# print("Cross-validated scores:", scores)
# print("Mean accuracy = ", scores.mean())


# Make cross validated predictions
predictions = cross_val_predict(model, df, y_clicks, cv=cv)

# plt.scatter(y, predictions)

accuracy = metrics.r2_score(y_clicks, predictions)
print("Cross-Predicted Accuracy (R2):", accuracy)
clicks_r2.append(accuracy)

from sklearn.metrics import mean_absolute_error
# print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
error_percent = mean_absolute_error(y_clicks, predictions)/y_clicks.mean()
print("Mean values: ", y_clicks.mean(), " | percent error: ",  error_percent)
clicks_error.append(error_percent)
###get coefficients
#     import numpy as np
#     print(pd.concat([pd.DataFrame(df.columns),pd.DataFrame(np.transpose(lm.coef_))], axis = 1))
# Out:
# WITH cross-promotion features
# Cross-Predicted Accuracy (R2): 0.886461728748
# Mean values:  3.207058633934087  | percent error:  0.159088134375
# Cross-Predicted Accuracy (R2): 0.886536098307
# Mean values:  7.869490478364804  | percent error:  0.0632804338117

# %%
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

for feat in features:
    train[feat] = np.log(train[feat] + 1)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = (np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)).astype(int)
train['share_bucket'] = (np.log(train['ext_twodays_stories_by_action_type__share']+1)).astype(int)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']

print('SHARES: Adjusted R2')
res = ols(y = y_share, x = train[features])
print(res.r2_adj)
print('CLICKS: Adjusted R2')
res = ols(y = y_clicks, x = train[features])
print(res.r2_adj)
# Out:
# SHARES: Adjusted R2
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0.894830196678
# CLICKS: Adjusted R2
# 0.906205131597

# %%
train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

log_scale = 0
# log_scale = 1

alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

if log_scale == 1:
    for feat in features:
        train[feat] = np.log(train[feat]+1)

# # ####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1)
train['share_bucket'] = np.log(train['ext_twodays_stories_by_action_type__share']+1)

if log_scale == 1:
    y_clicks = train['clicks_bucket']
    y_share = train['share_bucket']
else:
    y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
    y_share = train['ext_twodays_stories_by_action_type__share']

print('SHARES: Adjusted R2')
res = ols(y = y_share, x = train[features])
print(res.r2_adj)
print('CLICKS: Adjusted R2')
res = ols(y = y_clicks, x = train[features])
print(res.r2_adj)

print("WITH cross-promotion features!")

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

print('SHARES: Adjusted R2')
res = ols(y = y_share, x = train[features])
print(res.r2_adj)
print('CLICKS: Adjusted R2')
res = ols(y = y_clicks, x = train[features])
print(res.r2_adj)
# Out:
# WITHOUT cross-promotion features
# SHARES: Adjusted R2
# 0.765604208607
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# CLICKS: Adjusted R2
# 0.877583627753
# WITH cross-promotion features!
# SHARES: Adjusted R2
# 0.769762102327
# CLICKS: Adjusted R2
# 0.881668428064

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()

print("LINEAR REGRESSION!")

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

for feat in features:
    train[feat] = np.log(train[feat] + 1)

# ####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = np.log(train['ext_twodays_consumptions_by_type__link_clicks'] + 1)
train['share_bucket'] = np.log(train['ext_twodays_stories_by_action_type__share'] + 1)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']

# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']

X = train[features]

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

clicks_accuracy = []
clicks_error = []
shares_accuracy = []
shares_error = []

for train_index, test_index in kf.split(X):
    print("Shares: Fold = ", fold)
    y = y_share
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    shares_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    shares_error.append(error_percent)
    
    print("Clicks: Fold = ", fold)
    y = y_clicks
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    clicks_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    clicks_error.append(error_percent)
    fold += 1
print("Shares performance: Accuracy = ", np.mean(shares_accuracy), " ; Error (/100) = ", np.mean(shares_error))
print("Clicks performance: Accuracy = ", np.mean(clicks_accuracy), " ; Error (/100) = ", np.mean(clicks_error))
# Out:
# LINEAR REGRESSION!
# Shares: Fold =  0
# Cross-Predicted Accuracy (R2): 0.900497842647
# Mean values (share):  3.684855520514682  | percent error:  0.128983881432
# Clicks: Fold =  0
# Cross-Predicted Accuracy (R2): 0.920410804672
# Mean values (share):  8.365809142950564  | percent error:  0.0468028712912
# Shares: Fold =  1
# Cross-Predicted Accuracy (R2): 0.903078028097
# Mean values (share):  3.7152530387977025  | percent error:  0.12983244799
# Clicks: Fold =  1
# Cross-Predicted Accuracy (R2): 0.90279661774
# Mean values (share):  8.370074692176042  | percent error:  0.0490597410977
# Shares: Fold =  2
# Cross-Predicted Accuracy (R2): 0.897102960911
# Mean values (share):  3.658530372750752  | percent error:  0.130502778934
# Clicks: Fold =  2
# Cross-Predicted Accuracy (R2): 0.904633710558
# Mean values (share):  8.34164514264533  | percent error:  0.0488651805122
# Shares: Fold =  3
# Cross-Predicted Accuracy (R2): 0.898159713125
# Mean values (share):  3.6562492078925297  | percent error:  0.127931531788
# Clicks: Fold =  3
# Cross-Predicted Accuracy (R2): 0.904768998163
# Mean values (share):  8.342208531022433  | percent error:  0.0478533714091
# Shares: Fold =  4
# Cross-Predicted Accuracy (R2): 0.904092286281
# Mean values (share):  3.6645537400245054  | percent error:  0.12893133069
# Clicks: Fold =  4
# Cross-Predicted Accuracy (R2): 0.907581045527
# Mean values (share):  8.379647529429013  | percent error:  0.0481485795836
# Shares: Fold =  5
# Cross-Predicted Accuracy (R2): 0.898235337189
# Mean values (share):  3.6910719558799445  | percent error:  0.128639197809
# Clicks: Fold =  5
# Cross-Predicted Accuracy (R2): 0.905149867142
# Mean values (share):  8.361071840966009  | percent error:  0.048877624931
# Shares: Fold =  6
# Cross-Predicted Accuracy (R2): 0.907716055515
# Mean values (share):  3.684622396055637  | percent error:  0.125376247559
# Clicks: Fold =  6
# Cross-Predicted Accuracy (R2): 0.920233520295
# Mean values (share):  8.368715674627193  | percent error:  0.0469945423887
# Shares: Fold =  7
# Cross-Predicted Accuracy (R2): 0.903158830851
# Mean values (share):  3.69250858980415  | percent error:  0.126284113972
# Clicks: Fold =  7
# Cross-Predicted Accuracy (R2): 0.924319547299
# Mean values (share):  8.417282795591369  | percent error:  0.0457147622193
# Shares: Fold =  8
# Cross-Predicted Accuracy (R2): 0.898665339096
# Mean values (share):  3.623309533258402  | percent error:  0.129576793154
# Clicks: Fold =  8
# Cross-Predicted Accuracy (R2): 0.920472859967
# Mean values (share):  8.269870210441267  | percent error:  0.0467796729808
# Shares: Fold =  9
# Cross-Predicted Accuracy (R2): 0.889950490335
# Mean values (share):  3.694576323278429  | percent error:  0.131496369702
# Clicks: Fold =  9
# Cross-Predicted Accuracy (R2): 0.889954534246
# Mean values (share):  8.382468316412682  | percent error:  0.0511839787544
# Shares performance: Accuracy =  0.900065688405  ; Error (/100) =  0.128755469303
# Clicks performance: Accuracy =  0.910032150561  ; Error (/100) =  0.0480280325168

# %%
from sklearn.tree import DecisionTreeRegressor
clf = DecisionTreeRegressor(max_depth=10)

print("TREE REGRESSION!")

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
# for pg in all_pages:
#     features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = train['ext_twodays_consumptions_by_type__link_clicks']
train['share_bucket'] = train['ext_twodays_stories_by_action_type__share']

# y_clicks = train['clicks_bucket']
# y_share = train['share_bucket']

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

X = train[features]
y = y_clicks

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

clicks_accuracy = []
clicks_error = []
shares_accuracy = []
shares_error = []

for train_index, test_index in kf.split(X):
    print("Shares: Fold = ", fold)
    y = y_share
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    shares_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    shares_error.append(error_percent)
    
    print("Clicks: Fold = ", fold)
    y = y_clicks
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    clicks_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    clicks_error.append(error_percent)
    fold += 1
print("Shares performance: Accuracy = ", np.mean(shares_accuracy), " ; Error (/100) = ", np.mean(shares_error))
print("Clicks performance: Accuracy = ", np.mean(clicks_accuracy), " ; Error (/100) = ", np.mean(clicks_error))
# Out:
# TREE REGRESSION!
# Shares: Fold =  0
# Cross-Predicted Accuracy (R2): 0.968729850749
# Mean values (share):  294.69253490870034  | percent error:  0.241113660693
# Clicks: Fold =  0
# Cross-Predicted Accuracy (R2): 0.958449050304
# Mean values (share):  27626.113319011816  | percent error:  0.212473236853
# Shares: Fold =  1
# Cross-Predicted Accuracy (R2): 0.949024445732
# Mean values (share):  282.33360193392423  | percent error:  0.246546627263
# Clicks: Fold =  1
# Cross-Predicted Accuracy (R2): 0.941214850753
# Mean values (share):  25834.63819500403  | percent error:  0.213681274223
# Shares: Fold =  2
# Cross-Predicted Accuracy (R2): 0.941935035199
# Mean values (share):  269.3580445876981  | percent error:  0.238232352855
# Clicks: Fold =  2
# Cross-Predicted Accuracy (R2): 0.950197797236
# Mean values (share):  25656.395111469246  | percent error:  0.202011731373
# Shares: Fold =  3
# Cross-Predicted Accuracy (R2): 0.925382311375
# Mean values (share):  296.2070910556003  | percent error:  0.263528167674
# Clicks: Fold =  3
# Cross-Predicted Accuracy (R2): 0.95074056628
# Mean values (share):  27752.867311308084  | percent error:  0.224622584134
# Shares: Fold =  4
# Cross-Predicted Accuracy (R2): 0.943812000071
# Mean values (share):  303.52941176470586  | percent error:  0.262670040314
# Clicks: Fold =  4
# Cross-Predicted Accuracy (R2): 0.942362430277
# Mean values (share):  27355.95326349718  | percent error:  0.224634192947
# Shares: Fold =  5
# Cross-Predicted Accuracy (R2): 0.935614711844
# Mean values (share):  280.5216223475692  | percent error:  0.254581017559
# Clicks: Fold =  5
# Cross-Predicted Accuracy (R2): 0.952662746402
# Mean values (share):  26649.278538812785  | percent error:  0.200646850212
# Shares: Fold =  6
# Cross-Predicted Accuracy (R2): 0.964845969746
# Mean values (share):  272.4969110932044  | percent error:  0.225099480981
# Clicks: Fold =  6
# Cross-Predicted Accuracy (R2): 0.962207943001
# Mean values (share):  25960.782433521355  | percent error:  0.199512277071
# Shares: Fold =  7
# Cross-Predicted Accuracy (R2): 0.950343147128
# Mean values (share):  278.94869728713405  | percent error:  0.249672528685
# Clicks: Fold =  7
# Cross-Predicted Accuracy (R2): 0.936069015403
# Mean values (share):  25601.231802309965  | percent error:  0.209563469459
# Shares: Fold =  8
# Cross-Predicted Accuracy (R2): 0.964340032998
# Mean values (share):  308.34488315874296  | percent error:  0.265575615861
# Clicks: Fold =  8
# Cross-Predicted Accuracy (R2): 0.949165453955
# Mean values (share):  28751.74294923449  | percent error:  0.230945157086
# Shares: Fold =  9
# Cross-Predicted Accuracy (R2): 0.932978245618
# Mean values (share):  284.6988987375772  | percent error:  0.263947942827
# Clicks: Fold =  9
# Cross-Predicted Accuracy (R2): 0.935899083515
# Mean values (share):  24701.40182648402  | percent error:  0.208836779548
# Shares performance: Accuracy =  0.947700575046  ; Error (/100) =  0.251096743471
# Clicks performance: Accuracy =  0.947896893713  ; Error (/100) =  0.212692755291

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha=1.0)

print("RIDGE REGRESSION!")

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = train['ext_twodays_consumptions_by_type__link_clicks']
train['share_bucket'] = train['ext_twodays_stories_by_action_type__share']

# y_clicks = train['clicks_bucket']
# y_share = train['share_bucket']

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

X = train[features]
y = y_clicks

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

clicks_accuracy = []
clicks_error = []
shares_accuracy = []
shares_error = []

for train_index, test_index in kf.split(X):
    print("Shares: Fold = ", fold)
    y = y_share
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    shares_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    shares_error.append(error_percent)
    
    print("Clicks: Fold = ", fold)
    y = y_clicks
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    clicks_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    clicks_error.append(error_percent)
    fold += 1
print("Shares performance: Accuracy = ", np.mean(shares_accuracy), " ; Error (/100) = ", np.mean(shares_error))
print("Clicks performance: Accuracy = ", np.mean(clicks_accuracy), " ; Error (/100) = ", np.mean(clicks_error))
# Out:
# RIDGE REGRESSION!
# Shares: Fold =  0
# Cross-Predicted Accuracy (R2): 0.744896738191
# Mean values (share):  281.4344790547798  | percent error:  0.473589392417
# Clicks: Fold =  0
# Cross-Predicted Accuracy (R2): 0.874241143474
# Mean values (share):  26392.47717508056  | percent error:  0.313314146275
# Shares: Fold =  1
# Cross-Predicted Accuracy (R2): 0.586766085398
# Mean values (share):  274.4238517324738  | percent error:  0.47039317974
# Clicks: Fold =  1
# Cross-Predicted Accuracy (R2): 0.856201121035
# Mean values (share):  25609.04995970991  | percent error:  0.311387622022
# Shares: Fold =  2
# Cross-Predicted Accuracy (R2): 0.795309513194
# Mean values (share):  283.928283642224  | percent error:  0.444979080281
# Clicks: Fold =  2
# Cross-Predicted Accuracy (R2): 0.844322686271
# Mean values (share):  27158.252484555465  | percent error:  0.320343561604
# Shares: Fold =  3
# Cross-Predicted Accuracy (R2): 0.627662421537
# Mean values (share):  292.94117647058823  | percent error:  0.474531426666
# Clicks: Fold =  3
# Cross-Predicted Accuracy (R2): 0.880213136164
# Mean values (share):  26150.626376578028  | percent error:  0.308757048021
# Shares: Fold =  4
# Cross-Predicted Accuracy (R2): 0.804015145453
# Mean values (share):  302.33118452860595  | percent error:  0.488240504041
# Clicks: Fold =  4
# Cross-Predicted Accuracy (R2): 0.879512722119
# Mean values (share):  27375.63577759871  | percent error:  0.307304587931
# Shares: Fold =  5
# Cross-Predicted Accuracy (R2): 0.85206433932
# Mean values (share):  292.0760139672307  | percent error:  0.449791425785
# Clicks: Fold =  5
# Cross-Predicted Accuracy (R2): 0.912224501465
# Mean values (share):  25384.780821917808  | percent error:  0.290128166857
# Shares: Fold =  6
# Cross-Predicted Accuracy (R2): 0.780334944632
# Mean values (share):  310.5409615901155  | percent error:  0.489843924106
# Clicks: Fold =  6
# Cross-Predicted Accuracy (R2): 0.876881831617
# Mean values (share):  27368.864893902766  | percent error:  0.309185939919
# Shares: Fold =  7
# Cross-Predicted Accuracy (R2): 0.763910434672
# Mean values (share):  262.18452860596295  | percent error:  0.43747034991
# Clicks: Fold =  7
# Cross-Predicted Accuracy (R2): 0.907117582491
# Mean values (share):  25497.56271823798  | percent error:  0.27989368073
# Shares: Fold =  8
# Cross-Predicted Accuracy (R2): 0.77999523459
# Mean values (share):  300.96132151490735  | percent error:  0.473941257004
# Clicks: Fold =  8
# Cross-Predicted Accuracy (R2): 0.879935750883
# Mean values (share):  28278.44883158743  | percent error:  0.328992793999
# Shares: Fold =  9
# Cross-Predicted Accuracy (R2): 0.853864512111
# Mean values (share):  270.31345688960516  | percent error:  0.435397751662
# Clicks: Fold =  9
# Cross-Predicted Accuracy (R2): 0.900860431905
# Mean values (share):  26675.03706688155  | percent error:  0.307119685562
# Shares performance: Accuracy =  0.75888193691  ; Error (/100) =  0.463817829161
# Clicks performance: Accuracy =  0.881151090742  ; Error (/100) =  0.307642723292

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)

print("LASSO REGRESSION!")

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = train['ext_twodays_consumptions_by_type__link_clicks']
train['share_bucket'] = train['ext_twodays_stories_by_action_type__share']

# y_clicks = train['clicks_bucket']
# y_share = train['share_bucket']

y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
y_share = train['ext_twodays_stories_by_action_type__share']

X = train[features]
y = y_clicks

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

clicks_accuracy = []
clicks_error = []
shares_accuracy = []
shares_error = []

for train_index, test_index in kf.split(X):
    print("Shares: Fold = ", fold)
    y = y_share
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    shares_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    shares_error.append(error_percent)
    
    print("Clicks: Fold = ", fold)
    y = y_clicks
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    clicks_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (clicks): ", y_test.mean(), " | percent error: ",  error_percent)
    clicks_error.append(error_percent)
    fold += 1
print("Shares performance: Accuracy = ", np.mean(shares_accuracy), " ; Error (/100) = ", np.mean(shares_error))
print("Clicks performance: Accuracy = ", np.mean(clicks_accuracy), " ; Error (/100) = ", np.mean(clicks_error))
# Out:
# LASSO REGRESSION!
# Shares: Fold =  0
# /Users/eshwarchandrasekharan/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Cross-Predicted Accuracy (R2): 0.818969597524
# Mean values (share):  297.00402792696025  | percent error:  0.455174595818
# Clicks: Fold =  0
# Cross-Predicted Accuracy (R2): 0.874600138556
# Mean values (clicks):  26225.081901181526  | percent error:  0.306431797282
# Shares: Fold =  1
# Cross-Predicted Accuracy (R2): 0.572189150925
# Mean values (share):  282.03948428686545  | percent error:  0.491628932999
# Clicks: Fold =  1
# Cross-Predicted Accuracy (R2): 0.8779629555
# Mean values (clicks):  27205.837765243083  | percent error:  0.31227886317
# Shares: Fold =  2
# Cross-Predicted Accuracy (R2): 0.749147616117
# Mean values (share):  280.392425463336  | percent error:  0.449954181002
# Clicks: Fold =  2
# Cross-Predicted Accuracy (R2): 0.893326769957
# Mean values (clicks):  27344.282030620467  | percent error:  0.307103555461
# Shares: Fold =  3
# Cross-Predicted Accuracy (R2): 0.590787935013
# Mean values (share):  272.77733011012623  | percent error:  0.453996134194
# Clicks: Fold =  3
# Cross-Predicted Accuracy (R2): 0.82879162526
# Mean values (clicks):  25194.167069567553  | percent error:  0.298126258186
# Shares: Fold =  4
# Cross-Predicted Accuracy (R2): 0.819368908313
# Mean values (share):  264.32608111737846  | percent error:  0.429602152563
# Clicks: Fold =  4
# Cross-Predicted Accuracy (R2): 0.906972843554
# Mean values (clicks):  26957.235562718237  | percent error:  0.303402744194
# Shares: Fold =  5
# Cross-Predicted Accuracy (R2): 0.766793725125
# Mean values (share):  278.30566747246843  | percent error:  0.4642995052
# Clicks: Fold =  5
# Cross-Predicted Accuracy (R2): 0.883477622347
# Mean values (clicks):  25514.9911361805  | percent error:  0.294202769726
# Shares: Fold =  6
# Cross-Predicted Accuracy (R2): 0.84431229298
# Mean values (share):  309.29465484824067  | percent error:  0.497099367554
# Clicks: Fold =  6
# Cross-Predicted Accuracy (R2): 0.897251135748
# Mean values (clicks):  27163.476766048887  | percent error:  0.324521119444
# Shares: Fold =  7
# Cross-Predicted Accuracy (R2): 0.796657840632
# Mean values (share):  293.33091592801503  | percent error:  0.468768079333
# Clicks: Fold =  7
# Cross-Predicted Accuracy (R2): 0.846561475677
# Mean values (clicks):  26829.835079237175  | percent error:  0.319558845103
# Shares: Fold =  8
# Cross-Predicted Accuracy (R2): 0.769970923086
# Mean values (share):  292.2078968573731  | percent error:  0.468527434295
# Clicks: Fold =  8
# Cross-Predicted Accuracy (R2): 0.883834268472
# Mean values (clicks):  27358.426806338975  | percent error:  0.322198311195
# Shares: Fold =  9
# Cross-Predicted Accuracy (R2): 0.831167329318
# Mean values (share):  301.4525919957024  | percent error:  0.469104765175
# Clicks: Fold =  9
# Cross-Predicted Accuracy (R2): 0.897635959364
# Mean values (clicks):  26097.446951383292  | percent error:  0.296867806703
# Shares performance: Accuracy =  0.755936531903  ; Error (/100) =  0.464815514813
# Clicks performance: Accuracy =  0.879041479443  ; Error (/100) =  0.308469207046

# %%
print(1)
# Out:
# 1

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)

print("LASSO REGRESSION!")

train = pd.read_csv('jan_may_2017_links_cross_posting_info.csv')
##drop dups
# train = train.sort_values('ext_table1_firsthour_stats_date', ascending = False).drop_duplicates(subset=['buzz_post_buzz_id', 'ext_external_id'], keep = 'last')
all_pages = list(train.buzz_account_display_name.unique())

####RESTRICT PAGE-WISE
# train = train[train['buzz_account_display_name'] == 'BuzzFeed']

# print("WITHOUT cross-promotion features")

features = [
       'ext_table1_consumptions_by_type__link_clicks',
       'ext_table1_consumptions_by_type__other_clicks',
       'ext_table1_reactions_like_total',
       'ext_table1_stories_by_action_type__comment',
       'ext_table1_stories_by_action_type__like',
       'ext_table1_stories_by_action_type__share', 'ext_table1_engaged_fan',
       'ext_table1_fan_reach', 'ext_table1_impressions',
       'ext_table1_impressions_fan',
        ]

    
alt_inf = len(all_pages) + 1
train = train.replace(math.inf, alt_inf)

for feat in features:
    train[feat] = np.log(1+train[feat])

# ####add the category variable for each of the pages in col_pages
for pg in all_pages:
    features.append(pg)

###generate DFs for analysis - X and Y
df = train[features]

train['clicks_bucket'] = np.log(train['ext_twodays_consumptions_by_type__link_clicks']+1).astype(int)
train['share_bucket'] = np.log(train['ext_twodays_stories_by_action_type__share']+1).astype(int)

y_clicks = train['clicks_bucket']
y_share = train['share_bucket']
# y_clicks = train['ext_twodays_consumptions_by_type__link_clicks']
# y_share = train['ext_twodays_stories_by_action_type__share']

X = train[features]
y = y_clicks

from sklearn.model_selection import KFold

fold = 0
cv_folds = 10
kf = KFold(n_splits = cv_folds, shuffle = True)

clicks_accuracy = []
clicks_error = []
shares_accuracy = []
shares_error = []

for train_index, test_index in kf.split(X):
    print("Shares: Fold = ", fold)
    y = y_share
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
        
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    shares_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (share): ", y_test.mean(), " | percent error: ",  error_percent)
    shares_error.append(error_percent)
    
    print("Clicks: Fold = ", fold)
    y = y_clicks
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    
    accuracy = metrics.r2_score(y_test, y_pred)
    print("Cross-Predicted Accuracy (R2):", accuracy)
    clicks_accuracy.append(accuracy)
    from sklearn.metrics import mean_absolute_error
    # print("Mean Absolute Error: ", mean_absolute_error(y, predictions))
    error_percent = mean_absolute_error(y_test, y_pred)/y.mean()
    print("Mean values (clicks): ", y_test.mean(), " | percent error: ",  error_percent)
    clicks_error.append(error_percent)
    fold += 1
print("Shares performance: Accuracy = ", np.mean(shares_accuracy), " ; Error (/100) = ", np.mean(shares_error))
print("Clicks performance: Accuracy = ", np.mean(clicks_accuracy), " ; Error (/100) = ", np.mean(clicks_error))
# Out:
# LASSO REGRESSION!
# Shares: Fold =  0
# Cross-Predicted Accuracy (R2): 0.885257374687
# Mean values (share):  3.182062298603652  | percent error:  0.16198432836
# Clicks: Fold =  0
# Cross-Predicted Accuracy (R2): 0.901212613578
# Mean values (clicks):  7.832975295381311  | percent error:  0.0622757524836
# Shares: Fold =  1
# Cross-Predicted Accuracy (R2): 0.884355133998
# Mean values (share):  3.2377115229653506  | percent error:  0.15984850708
# Clicks: Fold =  1
# Cross-Predicted Accuracy (R2): 0.89264381131
# Mean values (clicks):  7.87402632285791  | percent error:  0.0621423430751
# Shares: Fold =  2
# Cross-Predicted Accuracy (R2): 0.886582003731
# Mean values (share):  3.2377115229653506  | percent error:  0.161292070671
# Clicks: Fold =  2
# Cross-Predicted Accuracy (R2): 0.904441318462
# Mean values (clicks):  7.9312382487241475  | percent error:  0.0608254740626
# Shares: Fold =  3
# Cross-Predicted Accuracy (R2): 0.887892933374
# Mean values (share):  3.231802309965082  | percent error:  0.160987238011
# Clicks: Fold =  3
# Cross-Predicted Accuracy (R2): 0.898543294828
# Mean values (clicks):  7.911899006177814  | percent error:  0.0610667325033
# Shares: Fold =  4
# Cross-Predicted Accuracy (R2): 0.882875075288
# Mean values (share):  3.191243620735966  | percent error:  0.161220818148
# Clicks: Fold =  4
# Cross-Predicted Accuracy (R2): 0.909676975606
# Mean values (clicks):  7.850120870265915  | percent error:  0.060559874419
# Shares: Fold =  5
# Cross-Predicted Accuracy (R2): 0.889626270417
# Mean values (share):  3.2135374697824335  | percent error:  0.160756552804
# Clicks: Fold =  5
# Cross-Predicted Accuracy (R2): 0.895168340374
# Mean values (clicks):  7.8691915122213265  | percent error:  0.0626683769313
# Shares: Fold =  6
# Cross-Predicted Accuracy (R2): 0.88366617993
# Mean values (share):  3.2081654579640073  | percent error:  0.162490560164
# Clicks: Fold =  6
# Cross-Predicted Accuracy (R2): 0.89819932659
# Mean values (clicks):  7.8611334944936875  | percent error:  0.0615560578906
# Shares: Fold =  7
# Cross-Predicted Accuracy (R2): 0.89873481655
# Mean values (share):  3.1850658071447757  | percent error:  0.153136023248
# Clicks: Fold =  7
# Cross-Predicted Accuracy (R2): 0.911707405344
# Mean values (clicks):  7.880741337630943  | percent error:  0.0596495821243
# Shares: Fold =  8
# Cross-Predicted Accuracy (R2): 0.894980817542
# Mean values (share):  3.252215954875101  | percent error:  0.156364112716
# Clicks: Fold =  8
# Cross-Predicted Accuracy (R2): 0.905175787196
# Mean values (clicks):  7.895782970722536  | percent error:  0.0619198164873
# Shares: Fold =  9
# Cross-Predicted Accuracy (R2): 0.893109719863
# Mean values (share):  3.131077088369594  | percent error:  0.157039446174
# Clicks: Fold =  9
# Cross-Predicted Accuracy (R2): 0.905859969819
# Mean values (clicks):  7.787805533172173  | percent error:  0.0622955181645
# Shares performance: Accuracy =  0.888708032538  ; Error (/100) =  0.159511965738
# Clicks performance: Accuracy =  0.902262884311  ; Error (/100) =  0.0614959528142

# %%
y
# Out:
# 0         9
# 1         7
# 2         9
# 3         8
# 4         6
# 5         9
# 6         7
# 7        10
# 8         7
# 9         9
# 10        5
# 11        7
# 12        5
# 13        7
# 14        5
# 15        4
# 16        8
# 17        8
# 18       10
# 19        8
# 20        8
# 21        9
# 22        9
# 23        9
# 24        7
# 25        8
# 26        6
# 27        9
# 28       12
# 29        7
#          ..
# 37201     8
# 37202     9
# 37203    10
# 37204     7
# 37205     7
# 37206    11
# 37207    11
# 37208     6
# 37209     6
# 37210     9
# 37211     7
# 37212     7
# 37213     9
# 37214     9
# 37215    10
# 37216     9
# 37217     9
# 37218     9
# 37219     9
# 37220     8
# 37221    11
# 37222    10
# 37223     4
# 37224     9
# 37225     2
# 37226     6
# 37227     7
# 37228     4
# 37229     8
# 37230     6
# Name: clicks_bucket, dtype: int64

# %%
y.hist()
